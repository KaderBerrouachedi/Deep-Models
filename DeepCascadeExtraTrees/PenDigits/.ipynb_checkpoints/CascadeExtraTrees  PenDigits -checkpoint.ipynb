# %%
#  imports 
import numpy as np
import pandas as pd
from math import sqrt 
from pprint import pprint
from numpy import array
from time import time

# %%
# load data
df=pd.read_csv('PenDigits_withoutdupl_norm_v01.csv')  

del df['id']
del df['Unnamed: 0']
df['outlier'] = df.outlier.apply(lambda label: 1 if label == "'yes'" else 0)

df.head()
# Out:
#    att1   att2  att3  att4  att5  att6  att7  att8   att9  att10  att11  \
# 0  48.0  100.0  20.0  80.0   0.0  51.0  55.0  43.0  100.0   56.0   90.0
# 1  38.0  100.0   4.0  85.0   0.0  53.0  58.0  46.0  100.0   52.0   88.0
# 2  53.0  100.0  25.0  70.0   0.0  39.0  50.0  34.0  100.0   42.0   85.0
# 3  12.0  100.0   0.0  71.0  25.0  43.0  86.0  44.0  100.0   75.0   90.0
# 4  26.0  100.0   0.0  83.0  23.0  51.0  83.0  42.0  100.0   55.0   79.0
#
#    att12  att13  att14  att15  att16  outlier
# 0   62.0   86.0   30.0   73.0    0.0        1
# 1   64.0   78.0   32.0   73.0    0.0        1
# 2   64.0   77.0   32.0   80.0    0.0        1
# 3   52.0   90.0   20.0   90.0    0.0        1
# 4   84.0   56.0   42.0   37.0    0.0        1

# %%
# df to values
df = df.values

# %%
# CascadeExtraTrees  
import argparse
import numpy as np
import sys
import pickle
from sklearn.metrics import accuracy_score
sys.path.insert(0, "lib")
from gcforest.gcforest import GCForest
from gcforest.utils.config_utils import load_json
config = load_json("./examples/PenDigits.json")  
gc = GCForest(config)

# %%
# train test
from sklearn.cross_validation import train_test_split
y = df[:,16]
X = df[:,0:16]

X_train,X_test,y_train,y_test = train_test_split(X, y, test_size=0.3, random_state=0)
# Out:
# /home/ubuntu/anaconda2/lib/python2.7/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
# count class
len(np.unique(y_train))
# Out:
# 2

# %%
  # X_enc is the concatenated predict_proba result of CascadeExtraTrees

X_train_enc, X_test_enc = gc.fit_transform(X_train, y_train, X_test=X_test, y_test=y_test)
# Out:
# [ 2018-07-30 23:06:42,618][cascade_classifier.fit_transform] X_groups_train.shape=[(6907, 16)],y_train.shape=(6907,),X_groups_test.shape=[(2961, 16)],y_test.shape=(2961,)
# [ 2018-07-30 23:06:42,619][cascade_classifier.fit_transform] group_dims=[16]
# [ 2018-07-30 23:06:42,621][cascade_classifier.fit_transform] group_starts=[0]
# [ 2018-07-30 23:06:42,622][cascade_classifier.fit_transform] group_ends=[16]
# [ 2018-07-30 23:06:42,622][cascade_classifier.fit_transform] X_train.shape=(6907, 16),X_test.shape=(2961, 16)
# [ 2018-07-30 23:06:42,624][cascade_classifier.fit_transform] [layer=0] look_indexs=[0], X_cur_train.shape=(6907, 16), X_cur_test.shape=(2961, 16)
# [ 2018-07-30 23:06:43,210][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_0.predict)=100.00%
# [ 2018-07-30 23:06:43,937][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_1.predict)=100.00%
# [ 2018-07-30 23:06:44,803][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_2.predict)=100.00%
# [ 2018-07-30 23:06:45,524][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_3.predict)=99.71%
# [ 2018-07-30 23:06:46,407][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_4.predict)=99.86%
# [ 2018-07-30 23:06:47,329][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_5.predict)=100.00%
# [ 2018-07-30 23:06:48,223][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_6.predict)=100.00%
# [ 2018-07-30 23:06:49,121][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_7.predict)=99.86%
# [ 2018-07-30 23:06:49,836][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_8.predict)=100.00%
# [ 2018-07-30 23:06:50,558][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_9.predict)=99.86%
# [ 2018-07-30 23:06:50,667][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_cv.predict)=99.93%
# [ 2018-07-30 23:06:50,668][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.test.predict)=99.97%
# [ 2018-07-30 23:06:50,669][cascade_classifier.calc_accuracy] Accuracy(layer_0 - train.classifier_average)=99.93%
# [ 2018-07-30 23:06:50,670][cascade_classifier.calc_accuracy] Accuracy(layer_0 - test.classifier_average)=99.97%
# [ 2018-07-30 23:06:50,671][cascade_classifier.fit_transform] [Result][Reach Max Layer] opt_layer_num=1, accuracy_train=99.93%, accuracy_test=99.97%

# %%
# predict
y_pred = gc.predict(X_test)
acc = accuracy_score(y_test, y_pred)
print("Test Accuracy of CascadeExtraTrees = {:.6f} %".format(acc * 100))
 # Matrix de confusion
from sklearn.metrics import classification_report, confusion_matrix
print(confusion_matrix(y_test,y_pred))
print('\n')
print(classification_report(y_test,y_pred))
# Out:
# [ 2018-07-30 23:06:50,679][cascade_classifier.transform] X_groups_test.shape=[(2961, 16)]
# [ 2018-07-30 23:06:50,680][cascade_classifier.transform] group_dims=[16]
# [ 2018-07-30 23:06:50,681][cascade_classifier.transform] X_test.shape=(2961, 16)
# [ 2018-07-30 23:06:50,682][cascade_classifier.transform] [layer=0] look_indexs=[0], X_cur_test.shape=(2961, 16)
# Test Accuracy of CascadeExtraTrees = 99.966228 %
# [[2957    0]
#  [   1    3]]
#
#
#              precision    recall  f1-score   support
#
#         0.0       1.00      1.00      1.00      2957
#         1.0       1.00      0.75      0.86         4
#
# avg / total       1.00      1.00      1.00      2961

# %%
#  predict_proba + Data 
X_test_enc = gc.transform(X_test)
X_train_enc = X_train_enc.reshape((X_train_enc.shape[0], -1))
X_test_enc = X_test_enc.reshape((X_test_enc.shape[0], -1))
X_train_origin = X_train.reshape((X_train.shape[0], -1))
X_test_origin = X_test.reshape((X_test.shape[0], -1))
X_train_enc = np.hstack((X_train_origin, X_train_enc))
X_test_enc = np.hstack((X_test_origin, X_test_enc))
# Out:
# [ 2018-07-30 23:06:52,915][cascade_classifier.transform] X_groups_test.shape=[(2961, 16)]
# [ 2018-07-30 23:06:52,916][cascade_classifier.transform] group_dims=[16]
# [ 2018-07-30 23:06:52,917][cascade_classifier.transform] X_test.shape=(2961, 16)
# [ 2018-07-30 23:06:52,918][cascade_classifier.transform] [layer=0] look_indexs=[0], X_cur_test.shape=(2961, 16)

# %%
# New data
X_train_new = X_train_enc
X_test_new  = X_test_enc

# %%
X_test_new.shape
# Out:
# (2961, 18)

# %%
X_train_new.shape
# Out:
# (6907, 18)

# %%
# Cascade ExtraTrees
config = load_json("./examples/PenDigitsgc.json")  
gc = GCForest(config)

X_train=X_train_enc
X_test=X_test_enc 
X_train_enc, X_test_enc = gc.fit_transform(X_train, y_train, X_test=X_test, y_test=y_test)
# Out:
# [ 2018-07-30 23:06:55,162][cascade_classifier.fit_transform] X_groups_train.shape=[(6907, 18)],y_train.shape=(6907,),X_groups_test.shape=[(2961, 18)],y_test.shape=(2961,)
# [ 2018-07-30 23:06:55,163][cascade_classifier.fit_transform] group_dims=[18]
# [ 2018-07-30 23:06:55,164][cascade_classifier.fit_transform] group_starts=[0]
# [ 2018-07-30 23:06:55,165][cascade_classifier.fit_transform] group_ends=[18]
# [ 2018-07-30 23:06:55,166][cascade_classifier.fit_transform] X_train.shape=(6907, 18),X_test.shape=(2961, 18)
# [ 2018-07-30 23:06:55,167][cascade_classifier.fit_transform] [layer=0] look_indexs=[0], X_cur_train.shape=(6907, 18), X_cur_test.shape=(2961, 18)
# [ 2018-07-30 23:06:55,673][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_0.predict)=100.00%
# [ 2018-07-30 23:06:56,393][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_1.predict)=100.00%
# [ 2018-07-30 23:06:57,126][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_2.predict)=100.00%
# [ 2018-07-30 23:06:57,993][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_3.predict)=99.71%
# [ 2018-07-30 23:06:58,850][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_4.predict)=100.00%
# [ 2018-07-30 23:06:59,572][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_5.predict)=100.00%
# [ 2018-07-30 23:07:00,289][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_6.predict)=100.00%
# [ 2018-07-30 23:07:01,010][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_7.predict)=100.00%
# [ 2018-07-30 23:07:01,729][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_8.predict)=100.00%
# [ 2018-07-30 23:07:02,568][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_9.predict)=99.86%
# [ 2018-07-30 23:07:02,789][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_cv.predict)=99.96%
# [ 2018-07-30 23:07:02,790][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.test.predict)=100.00%
# [ 2018-07-30 23:07:02,791][cascade_classifier.calc_accuracy] Accuracy(layer_0 - train.classifier_average)=99.96%
# [ 2018-07-30 23:07:02,793][cascade_classifier.calc_accuracy] Accuracy(layer_0 - test.classifier_average)=100.00%
# [ 2018-07-30 23:07:02,795][cascade_classifier.fit_transform] [layer=1] look_indexs=[0], X_cur_train.shape=(6907, 20), X_cur_test.shape=(2961, 20)
# [ 2018-07-30 23:07:03,298][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_0 - 10_folds.train_0.predict)=99.86%
# [ 2018-07-30 23:07:04,021][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_0 - 10_folds.train_1.predict)=100.00%
# [ 2018-07-30 23:07:04,893][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_0 - 10_folds.train_2.predict)=99.86%
# [ 2018-07-30 23:07:05,899][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_0 - 10_folds.train_3.predict)=100.00%
# [ 2018-07-30 23:07:06,890][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_0 - 10_folds.train_4.predict)=100.00%
# [ 2018-07-30 23:07:07,781][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_0 - 10_folds.train_5.predict)=100.00%
# [ 2018-07-30 23:07:08,521][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_0 - 10_folds.train_6.predict)=99.86%
# [ 2018-07-30 23:07:09,242][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_0 - 10_folds.train_7.predict)=99.86%
# [ 2018-07-30 23:07:09,962][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_0 - 10_folds.train_8.predict)=100.00%
# [ 2018-07-30 23:07:10,794][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_0 - 10_folds.train_9.predict)=100.00%
# [ 2018-07-30 23:07:11,016][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_0 - 10_folds.train_cv.predict)=99.94%
# [ 2018-07-30 23:07:11,018][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_0 - 10_folds.test.predict)=100.00%
# [ 2018-07-30 23:07:11,019][cascade_classifier.calc_accuracy] Accuracy(layer_1 - train.classifier_average)=99.94%
# [ 2018-07-30 23:07:11,020][cascade_classifier.calc_accuracy] Accuracy(layer_1 - test.classifier_average)=100.00%
# [ 2018-07-30 23:07:11,022][cascade_classifier.fit_transform] [layer=2] look_indexs=[0], X_cur_train.shape=(6907, 20), X_cur_test.shape=(2961, 20)
# [ 2018-07-30 23:07:11,524][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_0 - 10_folds.train_0.predict)=100.00%
# [ 2018-07-30 23:07:12,246][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_0 - 10_folds.train_1.predict)=100.00%
# [ 2018-07-30 23:07:12,968][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_0 - 10_folds.train_2.predict)=100.00%
# [ 2018-07-30 23:07:13,688][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_0 - 10_folds.train_3.predict)=99.86%
# [ 2018-07-30 23:07:14,406][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_0 - 10_folds.train_4.predict)=99.71%
# [ 2018-07-30 23:07:15,249][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_0 - 10_folds.train_5.predict)=100.00%
# [ 2018-07-30 23:07:16,103][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_0 - 10_folds.train_6.predict)=100.00%
# [ 2018-07-30 23:07:16,948][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_0 - 10_folds.train_7.predict)=99.86%
# [ 2018-07-30 23:07:17,682][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_0 - 10_folds.train_8.predict)=100.00%
# [ 2018-07-30 23:07:18,516][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_0 - 10_folds.train_9.predict)=100.00%
# [ 2018-07-30 23:07:18,742][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_0 - 10_folds.train_cv.predict)=99.94%
# [ 2018-07-30 23:07:18,743][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_0 - 10_folds.test.predict)=100.00%
# [ 2018-07-30 23:07:18,744][cascade_classifier.calc_accuracy] Accuracy(layer_2 - train.classifier_average)=99.94%
# [ 2018-07-30 23:07:18,745][cascade_classifier.calc_accuracy] Accuracy(layer_2 - test.classifier_average)=100.00%
# [ 2018-07-30 23:07:18,747][cascade_classifier.fit_transform] [layer=3] look_indexs=[0], X_cur_train.shape=(6907, 20), X_cur_test.shape=(2961, 20)
# [ 2018-07-30 23:07:19,251][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_0 - 10_folds.train_0.predict)=100.00%
# [ 2018-07-30 23:07:19,978][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_0 - 10_folds.train_1.predict)=100.00%
# [ 2018-07-30 23:07:20,845][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_0 - 10_folds.train_2.predict)=99.86%
# [ 2018-07-30 23:07:21,687][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_0 - 10_folds.train_3.predict)=99.86%
# [ 2018-07-30 23:07:22,608][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_0 - 10_folds.train_4.predict)=99.86%
# [ 2018-07-30 23:07:23,577][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_0 - 10_folds.train_5.predict)=100.00%
# [ 2018-07-30 23:07:24,700][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_0 - 10_folds.train_6.predict)=100.00%
# [ 2018-07-30 23:07:25,701][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_0 - 10_folds.train_7.predict)=100.00%
# [ 2018-07-30 23:07:26,707][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_0 - 10_folds.train_8.predict)=99.86%
# [ 2018-07-30 23:07:27,663][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_0 - 10_folds.train_9.predict)=99.86%
# [ 2018-07-30 23:07:27,888][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_0 - 10_folds.train_cv.predict)=99.93%
# [ 2018-07-30 23:07:27,890][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_0 - 10_folds.test.predict)=100.00%
# [ 2018-07-30 23:07:27,891][cascade_classifier.calc_accuracy] Accuracy(layer_3 - train.classifier_average)=99.93%
# [ 2018-07-30 23:07:27,892][cascade_classifier.calc_accuracy] Accuracy(layer_3 - test.classifier_average)=100.00%
# [ 2018-07-30 23:07:27,893][cascade_classifier.fit_transform] [Result][Optimal Level Detected] opt_layer_num=1, accuracy_train=99.96%, accuracy_test=100.00%

# %%
y_pred = gc.predict(X_test)
acc = accuracy_score(y_test, y_pred)
print("Test Accuracy of CascadeExtraTrees = {:.6f} %".format(acc * 100))
 # Matrix de confusion
from sklearn.metrics import classification_report, confusion_matrix
print(confusion_matrix(y_test,y_pred))
print('\n')
print(classification_report(y_test,y_pred))
# Out:
# [ 2018-07-30 23:07:27,904][cascade_classifier.transform] X_groups_test.shape=[(2961, 18)]
# [ 2018-07-30 23:07:27,905][cascade_classifier.transform] group_dims=[18]
# [ 2018-07-30 23:07:27,906][cascade_classifier.transform] X_test.shape=(2961, 18)
# [ 2018-07-30 23:07:27,908][cascade_classifier.transform] [layer=0] look_indexs=[0], X_cur_test.shape=(2961, 18)
# Test Accuracy of CascadeExtraTrees = 100.000000 %
# [[2957    0]
#  [   0    4]]
#
#
#              precision    recall  f1-score   support
#
#         0.0       1.00      1.00      1.00      2957
#         1.0       1.00      1.00      1.00         4
#
# avg / total       1.00      1.00      1.00      2961

# %%
# CascadeExtraTrees
def update(X_train,X_test):
    # update Estimators
    M = np.delete(X_train, (-1), axis=1)
    X_train= np.delete(M, (-1), axis=1)
    M = np.delete(X_test, (-1), axis=1)
    X_test = np.delete(M, (-1), axis=1)
    return X_train,X_test

def newdata(X_test_enc, X_train_enc):
    # Make Data + Estimators
    X_train_origin = X_train.reshape((X_train.shape[0], -1))
    X_test_origin = X_test.reshape((X_test.shape[0], -1))
    X_train_enc = np.hstack((X_train_origin, X_train_enc))
    X_test_enc = np.hstack((X_test_origin, X_test_enc))
    return X_test_enc, X_train_enc

Accuracy = []
def affiche():
    # predict
    y_pred = gc.predict(X_test)
    acc = accuracy_score(y_test, y_pred)
    print("Test Accuracy of CascadeExtraTrees = {:.6f} %".format(acc * 100),"Layer :",i)
    Accuracy.append(round(acc*100 , 2))
    # Matrix de confusion
    from sklearn.metrics import classification_report, confusion_matrix
    print(confusion_matrix(y_test,y_pred))
    print('\n')
    print(classification_report(y_test,y_pred))   
    
    
# Deep
t = []
for i in range (20):
    t0 = time()
    X_train,X_test=update(X_train,X_test)
    X_test_enc, X_train_enc=newdata(X_test_enc, X_train_enc)

    X_train=X_train_enc
    X_test=X_test_enc 
    
    config = load_json("./examples/PenDigitsgc.json")  
    gc = GCForest(config)
    X_train_enc, X_test_enc = gc.fit_transform(X_train, y_train, X_test=X_test, y_test=y_test) 
    tt = time() - t0
    affiche() 
    t.append(round(tt,2))
    print (" Time ",format(round(tt,3))," seconds")
# Out:
# [ 2018-07-30 23:07:30,174][cascade_classifier.fit_transform] X_groups_train.shape=[(6907, 18)],y_train.shape=(6907,),X_groups_test.shape=[(2961, 18)],y_test.shape=(2961,)
# [ 2018-07-30 23:07:30,175][cascade_classifier.fit_transform] group_dims=[18]
# [ 2018-07-30 23:07:30,176][cascade_classifier.fit_transform] group_starts=[0]
# [ 2018-07-30 23:07:30,177][cascade_classifier.fit_transform] group_ends=[18]
# [ 2018-07-30 23:07:30,178][cascade_classifier.fit_transform] X_train.shape=(6907, 18),X_test.shape=(2961, 18)
# [ 2018-07-30 23:07:30,179][cascade_classifier.fit_transform] [layer=0] look_indexs=[0], X_cur_train.shape=(6907, 18), X_cur_test.shape=(2961, 18)
# [ 2018-07-30 23:07:30,690][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_0.predict)=100.00%
# [ 2018-07-30 23:07:31,413][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_1.predict)=100.00%
# [ 2018-07-30 23:07:32,252][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_2.predict)=100.00%
# [ 2018-07-30 23:07:33,089][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_3.predict)=99.71%
# [ 2018-07-30 23:07:33,816][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_4.predict)=100.00%
# [ 2018-07-30 23:07:34,539][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_5.predict)=100.00%
# [ 2018-07-30 23:07:35,260][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_6.predict)=100.00%
# [ 2018-07-30 23:07:35,984][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_7.predict)=99.86%
# [ 2018-07-30 23:07:36,876][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_8.predict)=100.00%
# [ 2018-07-30 23:07:37,590][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_9.predict)=99.86%
# [ 2018-07-30 23:07:37,815][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_cv.predict)=99.94%
# [ 2018-07-30 23:07:37,816][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.test.predict)=100.00%
# [ 2018-07-30 23:07:37,817][cascade_classifier.calc_accuracy] Accuracy(layer_0 - train.classifier_average)=99.94%
# [ 2018-07-30 23:07:37,818][cascade_classifier.calc_accuracy] Accuracy(layer_0 - test.classifier_average)=100.00%
# [ 2018-07-30 23:07:37,820][cascade_classifier.fit_transform] [layer=1] look_indexs=[0], X_cur_train.shape=(6907, 20), X_cur_test.shape=(2961, 20)
# [ 2018-07-30 23:07:38,321][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_0 - 10_folds.train_0.predict)=99.86%
# [ 2018-07-30 23:07:39,040][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_0 - 10_folds.train_1.predict)=100.00%
# [ 2018-07-30 23:07:39,913][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_0 - 10_folds.train_2.predict)=99.86%
# [ 2018-07-30 23:07:40,638][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_0 - 10_folds.train_3.predict)=100.00%
# [ 2018-07-30 23:07:41,551][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_0 - 10_folds.train_4.predict)=100.00%
# [ 2018-07-30 23:07:42,712][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_0 - 10_folds.train_5.predict)=100.00%
# [ 2018-07-30 23:07:43,610][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_0 - 10_folds.train_6.predict)=99.86%
# [ 2018-07-30 23:07:44,588][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_0 - 10_folds.train_7.predict)=99.86%
# [ 2018-07-30 23:07:45,555][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_0 - 10_folds.train_8.predict)=100.00%
# [ 2018-07-30 23:07:46,551][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_0 - 10_folds.train_9.predict)=99.86%
# [ 2018-07-30 23:07:46,778][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_0 - 10_folds.train_cv.predict)=99.93%
# [ 2018-07-30 23:07:46,779][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_0 - 10_folds.test.predict)=100.00%
# [ 2018-07-30 23:07:46,780][cascade_classifier.calc_accuracy] Accuracy(layer_1 - train.classifier_average)=99.93%
# [ 2018-07-30 23:07:46,781][cascade_classifier.calc_accuracy] Accuracy(layer_1 - test.classifier_average)=100.00%
# [ 2018-07-30 23:07:46,783][cascade_classifier.fit_transform] [layer=2] look_indexs=[0], X_cur_train.shape=(6907, 20), X_cur_test.shape=(2961, 20)
# [ 2018-07-30 23:07:47,409][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_0 - 10_folds.train_0.predict)=99.86%
# [ 2018-07-30 23:07:48,264][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_0 - 10_folds.train_1.predict)=100.00%
# [ 2018-07-30 23:07:49,126][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_0 - 10_folds.train_2.predict)=100.00%
# [ 2018-07-30 23:07:49,993][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_0 - 10_folds.train_3.predict)=99.86%
# [ 2018-07-30 23:07:51,006][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_0 - 10_folds.train_4.predict)=99.71%
# [ 2018-07-30 23:07:52,041][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_0 - 10_folds.train_5.predict)=100.00%
# [ 2018-07-30 23:07:52,922][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_0 - 10_folds.train_6.predict)=100.00%
# [ 2018-07-30 23:07:53,773][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_0 - 10_folds.train_7.predict)=99.86%
# [ 2018-07-30 23:07:54,630][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_0 - 10_folds.train_8.predict)=100.00%
# [ 2018-07-30 23:07:55,474][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_0 - 10_folds.train_9.predict)=100.00%
# [ 2018-07-30 23:07:55,697][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_0 - 10_folds.train_cv.predict)=99.93%
# [ 2018-07-30 23:07:55,698][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_0 - 10_folds.test.predict)=100.00%
# [ 2018-07-30 23:07:55,699][cascade_classifier.calc_accuracy] Accuracy(layer_2 - train.classifier_average)=99.93%
# [ 2018-07-30 23:07:55,700][cascade_classifier.calc_accuracy] Accuracy(layer_2 - test.classifier_average)=100.00%
# [ 2018-07-30 23:07:55,701][cascade_classifier.fit_transform] [layer=3] look_indexs=[0], X_cur_train.shape=(6907, 20), X_cur_test.shape=(2961, 20)
# [ 2018-07-30 23:07:56,216][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_0 - 10_folds.train_0.predict)=100.00%
# [ 2018-07-30 23:07:57,068][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_0 - 10_folds.train_1.predict)=99.86%
# [ 2018-07-30 23:07:57,802][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_0 - 10_folds.train_2.predict)=99.86%
# [ 2018-07-30 23:07:58,409][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_0 - 10_folds.train_3.predict)=99.86%
# [ 2018-07-30 23:07:59,016][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_0 - 10_folds.train_4.predict)=99.86%
# [ 2018-07-30 23:07:59,740][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_0 - 10_folds.train_5.predict)=100.00%
# [ 2018-07-30 23:08:00,462][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_0 - 10_folds.train_6.predict)=100.00%
# [ 2018-07-30 23:08:01,188][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_0 - 10_folds.train_7.predict)=100.00%
# [ 2018-07-30 23:08:01,914][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_0 - 10_folds.train_8.predict)=99.86%
# [ 2018-07-30 23:08:02,643][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_0 - 10_folds.train_9.predict)=99.86%
# [ 2018-07-30 23:08:02,867][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_0 - 10_folds.train_cv.predict)=99.91%
# [ 2018-07-30 23:08:02,868][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_0 - 10_folds.test.predict)=100.00%
# [ 2018-07-30 23:08:02,869][cascade_classifier.calc_accuracy] Accuracy(layer_3 - train.classifier_average)=99.91%
# [ 2018-07-30 23:08:02,870][cascade_classifier.calc_accuracy] Accuracy(layer_3 - test.classifier_average)=100.00%
# [ 2018-07-30 23:08:02,870][cascade_classifier.fit_transform] [Result][Optimal Level Detected] opt_layer_num=1, accuracy_train=99.94%, accuracy_test=100.00%
# [ 2018-07-30 23:08:02,875][cascade_classifier.transform] X_groups_test.shape=[(2961, 18)]
# [ 2018-07-30 23:08:02,876][cascade_classifier.transform] group_dims=[18]
# [ 2018-07-30 23:08:02,877][cascade_classifier.transform] X_test.shape=(2961, 18)
# [ 2018-07-30 23:08:02,878][cascade_classifier.transform] [layer=0] look_indexs=[0], X_cur_test.shape=(2961, 18)
# [ 2018-07-30 23:08:05,143][cascade_classifier.fit_transform] X_groups_train.shape=[(6907, 18)],y_train.shape=(6907,),X_groups_test.shape=[(2961, 18)],y_test.shape=(2961,)
# [ 2018-07-30 23:08:05,145][cascade_classifier.fit_transform] group_dims=[18]
# [ 2018-07-30 23:08:05,145][cascade_classifier.fit_transform] group_starts=[0]
# [ 2018-07-30 23:08:05,146][cascade_classifier.fit_transform] group_ends=[18]
# [ 2018-07-30 23:08:05,147][cascade_classifier.fit_transform] X_train.shape=(6907, 18),X_test.shape=(2961, 18)
# [ 2018-07-30 23:08:05,148][cascade_classifier.fit_transform] [layer=0] look_indexs=[0], X_cur_train.shape=(6907, 18), X_cur_test.shape=(2961, 18)
# ('Test Accuracy of CascadeExtraTrees = 100.000000 %', 'Layer :', 0)
# [[2957    0]
#  [   0    4]]
#
#
#              precision    recall  f1-score   support
#
#         0.0       1.00      1.00      1.00      2957
#         1.0       1.00      1.00      1.00         4
#
# avg / total       1.00      1.00      1.00      2961
#
# (' Time ', '32.704', ' seconds')
# [ 2018-07-30 23:08:05,655][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_0.predict)=100.00%
# [ 2018-07-30 23:08:06,376][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_1.predict)=100.00%
# [ 2018-07-30 23:08:07,096][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_2.predict)=100.00%
# [ 2018-07-30 23:08:07,703][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_3.predict)=99.71%
# [ 2018-07-30 23:08:08,419][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_4.predict)=99.86%
# [ 2018-07-30 23:08:09,138][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_5.predict)=100.00%
# [ 2018-07-30 23:08:09,862][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_6.predict)=100.00%
# [ 2018-07-30 23:08:10,589][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_7.predict)=99.71%
# [ 2018-07-30 23:08:11,314][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_8.predict)=100.00%
# [ 2018-07-30 23:08:12,032][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_9.predict)=99.86%
# [ 2018-07-30 23:08:12,255][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_cv.predict)=99.91%
# [ 2018-07-30 23:08:12,256][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.test.predict)=100.00%
# [ 2018-07-30 23:08:12,257][cascade_classifier.calc_accuracy] Accuracy(layer_0 - train.classifier_average)=99.91%
# [ 2018-07-30 23:08:12,258][cascade_classifier.calc_accuracy] Accuracy(layer_0 - test.classifier_average)=100.00%
# [ 2018-07-30 23:08:12,260][cascade_classifier.fit_transform] [layer=1] look_indexs=[0], X_cur_train.shape=(6907, 20), X_cur_test.shape=(2961, 20)
# [ 2018-07-30 23:08:12,886][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_0 - 10_folds.train_0.predict)=99.86%
# [ 2018-07-30 23:08:13,613][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_0 - 10_folds.train_1.predict)=99.86%
# [ 2018-07-30 23:08:14,338][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_0 - 10_folds.train_2.predict)=99.86%
# [ 2018-07-30 23:08:15,167][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_0 - 10_folds.train_3.predict)=100.00%
# [ 2018-07-30 23:08:16,048][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_0 - 10_folds.train_4.predict)=99.86%
# [ 2018-07-30 23:08:16,925][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_0 - 10_folds.train_5.predict)=100.00%
# [ 2018-07-30 23:08:17,809][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_0 - 10_folds.train_6.predict)=99.86%
# [ 2018-07-30 23:08:18,674][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_0 - 10_folds.train_7.predict)=99.86%
# [ 2018-07-30 23:08:19,540][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_0 - 10_folds.train_8.predict)=100.00%
# [ 2018-07-30 23:08:20,381][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_0 - 10_folds.train_9.predict)=99.86%
# [ 2018-07-30 23:08:20,628][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_0 - 10_folds.train_cv.predict)=99.90%
# [ 2018-07-30 23:08:20,629][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_0 - 10_folds.test.predict)=100.00%
# [ 2018-07-30 23:08:20,631][cascade_classifier.calc_accuracy] Accuracy(layer_1 - train.classifier_average)=99.90%
# [ 2018-07-30 23:08:20,632][cascade_classifier.calc_accuracy] Accuracy(layer_1 - test.classifier_average)=100.00%
# [ 2018-07-30 23:08:20,634][cascade_classifier.fit_transform] [layer=2] look_indexs=[0], X_cur_train.shape=(6907, 20), X_cur_test.shape=(2961, 20)
# [ 2018-07-30 23:08:21,266][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_0 - 10_folds.train_0.predict)=99.86%
# [ 2018-07-30 23:08:22,131][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_0 - 10_folds.train_1.predict)=100.00%
# [ 2018-07-30 23:08:22,861][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_0 - 10_folds.train_2.predict)=100.00%
# [ 2018-07-30 23:08:23,586][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_0 - 10_folds.train_3.predict)=99.86%
# [ 2018-07-30 23:08:24,315][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_0 - 10_folds.train_4.predict)=99.71%
# [ 2018-07-30 23:08:25,038][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_0 - 10_folds.train_5.predict)=100.00%
# [ 2018-07-30 23:08:25,875][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_0 - 10_folds.train_6.predict)=100.00%
# [ 2018-07-30 23:08:26,716][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_0 - 10_folds.train_7.predict)=99.86%
# [ 2018-07-30 23:08:27,438][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_0 - 10_folds.train_8.predict)=99.86%
# [ 2018-07-30 23:08:28,167][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_0 - 10_folds.train_9.predict)=100.00%
# [ 2018-07-30 23:08:28,389][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_0 - 10_folds.train_cv.predict)=99.91%
# [ 2018-07-30 23:08:28,390][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_0 - 10_folds.test.predict)=100.00%
# [ 2018-07-30 23:08:28,391][cascade_classifier.calc_accuracy] Accuracy(layer_2 - train.classifier_average)=99.91%
# [ 2018-07-30 23:08:28,392][cascade_classifier.calc_accuracy] Accuracy(layer_2 - test.classifier_average)=100.00%
# [ 2018-07-30 23:08:28,394][cascade_classifier.fit_transform] [layer=3] look_indexs=[0], X_cur_train.shape=(6907, 20), X_cur_test.shape=(2961, 20)
# [ 2018-07-30 23:08:28,901][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_0 - 10_folds.train_0.predict)=99.86%
# [ 2018-07-30 23:08:29,626][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_0 - 10_folds.train_1.predict)=100.00%
# [ 2018-07-30 23:08:30,506][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_0 - 10_folds.train_2.predict)=99.86%
# [ 2018-07-30 23:08:31,231][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_0 - 10_folds.train_3.predict)=99.86%
# [ 2018-07-30 23:08:31,953][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_0 - 10_folds.train_4.predict)=99.86%
# [ 2018-07-30 23:08:32,673][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_0 - 10_folds.train_5.predict)=100.00%
# [ 2018-07-30 23:08:33,393][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_0 - 10_folds.train_6.predict)=100.00%
# [ 2018-07-30 23:08:34,119][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_0 - 10_folds.train_7.predict)=100.00%
# [ 2018-07-30 23:08:34,957][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_0 - 10_folds.train_8.predict)=99.86%
# [ 2018-07-30 23:08:35,686][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_0 - 10_folds.train_9.predict)=99.86%
# [ 2018-07-30 23:08:35,909][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_0 - 10_folds.train_cv.predict)=99.91%
# [ 2018-07-30 23:08:35,910][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_0 - 10_folds.test.predict)=100.00%
# [ 2018-07-30 23:08:35,911][cascade_classifier.calc_accuracy] Accuracy(layer_3 - train.classifier_average)=99.91%
# [ 2018-07-30 23:08:35,912][cascade_classifier.calc_accuracy] Accuracy(layer_3 - test.classifier_average)=100.00%
# [ 2018-07-30 23:08:35,913][cascade_classifier.fit_transform] [Result][Optimal Level Detected] opt_layer_num=1, accuracy_train=99.91%, accuracy_test=100.00%
# [ 2018-07-30 23:08:35,917][cascade_classifier.transform] X_groups_test.shape=[(2961, 18)]
# [ 2018-07-30 23:08:35,918][cascade_classifier.transform] group_dims=[18]
# [ 2018-07-30 23:08:35,919][cascade_classifier.transform] X_test.shape=(2961, 18)
# [ 2018-07-30 23:08:35,920][cascade_classifier.transform] [layer=0] look_indexs=[0], X_cur_test.shape=(2961, 18)
# [ 2018-07-30 23:08:38,143][cascade_classifier.fit_transform] X_groups_train.shape=[(6907, 18)],y_train.shape=(6907,),X_groups_test.shape=[(2961, 18)],y_test.shape=(2961,)
# [ 2018-07-30 23:08:38,144][cascade_classifier.fit_transform] group_dims=[18]
# [ 2018-07-30 23:08:38,145][cascade_classifier.fit_transform] group_starts=[0]
# [ 2018-07-30 23:08:38,146][cascade_classifier.fit_transform] group_ends=[18]
# [ 2018-07-30 23:08:38,147][cascade_classifier.fit_transform] X_train.shape=(6907, 18),X_test.shape=(2961, 18)
# [ 2018-07-30 23:08:38,148][cascade_classifier.fit_transform] [layer=0] look_indexs=[0], X_cur_train.shape=(6907, 18), X_cur_test.shape=(2961, 18)
# ('Test Accuracy of CascadeExtraTrees = 100.000000 %', 'Layer :', 1)
# [[2957    0]
#  [   0    4]]
#
#
#              precision    recall  f1-score   support
#
#         0.0       1.00      1.00      1.00      2957
#         1.0       1.00      1.00      1.00         4
#
# avg / total       1.00      1.00      1.00      2961
#
# (' Time ', '30.777', ' seconds')
# [ 2018-07-30 23:08:38,659][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_0.predict)=100.00%
# [ 2018-07-30 23:08:39,496][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_1.predict)=100.00%
# [ 2018-07-30 23:08:40,342][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_2.predict)=100.00%
# [ 2018-07-30 23:08:41,065][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_3.predict)=99.71%
# [ 2018-07-30 23:08:41,795][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_4.predict)=99.86%
# [ 2018-07-30 23:08:42,634][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_5.predict)=100.00%
# [ 2018-07-30 23:08:43,361][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_6.predict)=100.00%
# [ 2018-07-30 23:08:44,069][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_7.predict)=99.71%
# [ 2018-07-30 23:08:44,790][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_8.predict)=100.00%
# [ 2018-07-30 23:08:45,512][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_9.predict)=99.86%
# [ 2018-07-30 23:08:45,735][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_cv.predict)=99.91%
# [ 2018-07-30 23:08:45,736][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.test.predict)=100.00%
# [ 2018-07-30 23:08:45,737][cascade_classifier.calc_accuracy] Accuracy(layer_0 - train.classifier_average)=99.91%
# [ 2018-07-30 23:08:45,737][cascade_classifier.calc_accuracy] Accuracy(layer_0 - test.classifier_average)=100.00%
# [ 2018-07-30 23:08:45,739][cascade_classifier.fit_transform] [layer=1] look_indexs=[0], X_cur_train.shape=(6907, 20), X_cur_test.shape=(2961, 20)
# [ 2018-07-30 23:08:46,246][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_0 - 10_folds.train_0.predict)=99.71%
# [ 2018-07-30 23:08:46,970][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_0 - 10_folds.train_1.predict)=99.86%
# [ 2018-07-30 23:08:47,583][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_0 - 10_folds.train_2.predict)=99.86%
# [ 2018-07-30 23:08:48,302][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_0 - 10_folds.train_3.predict)=100.00%
# [ 2018-07-30 23:08:49,022][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_0 - 10_folds.train_4.predict)=100.00%
# [ 2018-07-30 23:08:49,746][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_0 - 10_folds.train_5.predict)=100.00%
# [ 2018-07-30 23:08:50,584][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_0 - 10_folds.train_6.predict)=99.86%
# [ 2018-07-30 23:08:51,310][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_0 - 10_folds.train_7.predict)=99.71%
# [ 2018-07-30 23:08:52,031][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_0 - 10_folds.train_8.predict)=100.00%
# [ 2018-07-30 23:08:52,756][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_0 - 10_folds.train_9.predict)=99.86%
# [ 2018-07-30 23:08:52,979][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_0 - 10_folds.train_cv.predict)=99.88%
# [ 2018-07-30 23:08:52,980][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_0 - 10_folds.test.predict)=100.00%
# [ 2018-07-30 23:08:52,981][cascade_classifier.calc_accuracy] Accuracy(layer_1 - train.classifier_average)=99.88%
# [ 2018-07-30 23:08:52,982][cascade_classifier.calc_accuracy] Accuracy(layer_1 - test.classifier_average)=100.00%
# [ 2018-07-30 23:08:52,984][cascade_classifier.fit_transform] [layer=2] look_indexs=[0], X_cur_train.shape=(6907, 20), X_cur_test.shape=(2961, 20)
# [ 2018-07-30 23:08:53,488][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_0 - 10_folds.train_0.predict)=99.86%
# [ 2018-07-30 23:08:54,215][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_0 - 10_folds.train_1.predict)=100.00%
# [ 2018-07-30 23:08:55,088][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_0 - 10_folds.train_2.predict)=100.00%
# [ 2018-07-30 23:08:55,818][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_0 - 10_folds.train_3.predict)=99.86%
# [ 2018-07-30 23:08:56,541][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_0 - 10_folds.train_4.predict)=99.71%
# [ 2018-07-30 23:08:57,264][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_0 - 10_folds.train_5.predict)=99.86%
# [ 2018-07-30 23:08:58,111][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_0 - 10_folds.train_6.predict)=99.86%
# [ 2018-07-30 23:08:58,858][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_0 - 10_folds.train_7.predict)=99.71%
# [ 2018-07-30 23:08:59,699][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_0 - 10_folds.train_8.predict)=99.86%
# [ 2018-07-30 23:09:00,539][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_0 - 10_folds.train_9.predict)=100.00%
# [ 2018-07-30 23:09:00,762][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_0 - 10_folds.train_cv.predict)=99.87%
# [ 2018-07-30 23:09:00,763][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_0 - 10_folds.test.predict)=100.00%
# [ 2018-07-30 23:09:00,764][cascade_classifier.calc_accuracy] Accuracy(layer_2 - train.classifier_average)=99.87%
# [ 2018-07-30 23:09:00,765][cascade_classifier.calc_accuracy] Accuracy(layer_2 - test.classifier_average)=100.00%
# [ 2018-07-30 23:09:00,767][cascade_classifier.fit_transform] [layer=3] look_indexs=[0], X_cur_train.shape=(6907, 20), X_cur_test.shape=(2961, 20)
# [ 2018-07-30 23:09:01,390][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_0 - 10_folds.train_0.predict)=99.86%
# [ 2018-07-30 23:09:02,232][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_0 - 10_folds.train_1.predict)=100.00%
# [ 2018-07-30 23:09:02,954][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_0 - 10_folds.train_2.predict)=99.86%
# [ 2018-07-30 23:09:03,675][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_0 - 10_folds.train_3.predict)=99.86%
# [ 2018-07-30 23:09:04,402][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_0 - 10_folds.train_4.predict)=99.86%
# [ 2018-07-30 23:09:05,128][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_0 - 10_folds.train_5.predict)=100.00%
# [ 2018-07-30 23:09:05,856][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_0 - 10_folds.train_6.predict)=100.00%
# [ 2018-07-30 23:09:06,697][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_0 - 10_folds.train_7.predict)=100.00%
# [ 2018-07-30 23:09:07,435][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_0 - 10_folds.train_8.predict)=99.86%
# [ 2018-07-30 23:09:08,197][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_0 - 10_folds.train_9.predict)=99.86%
# [ 2018-07-30 23:09:08,420][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_0 - 10_folds.train_cv.predict)=99.91%
# [ 2018-07-30 23:09:08,421][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_0 - 10_folds.test.predict)=100.00%
# [ 2018-07-30 23:09:08,422][cascade_classifier.calc_accuracy] Accuracy(layer_3 - train.classifier_average)=99.91%
# [ 2018-07-30 23:09:08,423][cascade_classifier.calc_accuracy] Accuracy(layer_3 - test.classifier_average)=100.00%
# [ 2018-07-30 23:09:08,424][cascade_classifier.fit_transform] [Result][Optimal Level Detected] opt_layer_num=1, accuracy_train=99.91%, accuracy_test=100.00%
# [ 2018-07-30 23:09:08,429][cascade_classifier.transform] X_groups_test.shape=[(2961, 18)]
# [ 2018-07-30 23:09:08,431][cascade_classifier.transform] group_dims=[18]
# [ 2018-07-30 23:09:08,432][cascade_classifier.transform] X_test.shape=(2961, 18)
# [ 2018-07-30 23:09:08,433][cascade_classifier.transform] [layer=0] look_indexs=[0], X_cur_test.shape=(2961, 18)
# [ 2018-07-30 23:09:10,667][cascade_classifier.fit_transform] X_groups_train.shape=[(6907, 18)],y_train.shape=(6907,),X_groups_test.shape=[(2961, 18)],y_test.shape=(2961,)
# [ 2018-07-30 23:09:10,668][cascade_classifier.fit_transform] group_dims=[18]
# [ 2018-07-30 23:09:10,668][cascade_classifier.fit_transform] group_starts=[0]
# [ 2018-07-30 23:09:10,669][cascade_classifier.fit_transform] group_ends=[18]
# [ 2018-07-30 23:09:10,670][cascade_classifier.fit_transform] X_train.shape=(6907, 18),X_test.shape=(2961, 18)
# [ 2018-07-30 23:09:10,671][cascade_classifier.fit_transform] [layer=0] look_indexs=[0], X_cur_train.shape=(6907, 18), X_cur_test.shape=(2961, 18)
# ('Test Accuracy of CascadeExtraTrees = 100.000000 %', 'Layer :', 2)
# [[2957    0]
#  [   0    4]]
#
#
#              precision    recall  f1-score   support
#
#         0.0       1.00      1.00      1.00      2957
#         1.0       1.00      1.00      1.00         4
#
# avg / total       1.00      1.00      1.00      2961
#
# (' Time ', '30.289', ' seconds')
# [ 2018-07-30 23:09:11,176][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_0.predict)=100.00%
# [ 2018-07-30 23:09:11,900][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_1.predict)=100.00%
# [ 2018-07-30 23:09:12,625][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_2.predict)=100.00%
# [ 2018-07-30 23:09:13,347][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_3.predict)=99.71%
# [ 2018-07-30 23:09:14,073][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_4.predict)=99.71%
# [ 2018-07-30 23:09:14,799][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_5.predict)=100.00%
# [ 2018-07-30 23:09:15,524][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_6.predict)=100.00%
# [ 2018-07-30 23:09:16,373][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_7.predict)=99.71%
# [ 2018-07-30 23:09:17,222][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_8.predict)=100.00%
# [ 2018-07-30 23:09:18,102][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_9.predict)=99.86%
# [ 2018-07-30 23:09:18,334][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_cv.predict)=99.90%
# [ 2018-07-30 23:09:18,335][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.test.predict)=100.00%
# [ 2018-07-30 23:09:18,336][cascade_classifier.calc_accuracy] Accuracy(layer_0 - train.classifier_average)=99.90%
# [ 2018-07-30 23:09:18,337][cascade_classifier.calc_accuracy] Accuracy(layer_0 - test.classifier_average)=100.00%
# [ 2018-07-30 23:09:18,339][cascade_classifier.fit_transform] [layer=1] look_indexs=[0], X_cur_train.shape=(6907, 20), X_cur_test.shape=(2961, 20)
# [ 2018-07-30 23:09:18,969][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_0 - 10_folds.train_0.predict)=99.86%
# [ 2018-07-30 23:09:19,800][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_0 - 10_folds.train_1.predict)=99.86%
# [ 2018-07-30 23:09:20,679][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_0 - 10_folds.train_2.predict)=99.86%
# [ 2018-07-30 23:09:21,545][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_0 - 10_folds.train_3.predict)=100.00%
# [ 2018-07-30 23:09:22,411][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_0 - 10_folds.train_4.predict)=99.86%
# [ 2018-07-30 23:09:23,256][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_0 - 10_folds.train_5.predict)=99.86%
# [ 2018-07-30 23:09:23,990][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_0 - 10_folds.train_6.predict)=99.86%
# [ 2018-07-30 23:09:24,715][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_0 - 10_folds.train_7.predict)=99.86%
# [ 2018-07-30 23:09:25,551][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_0 - 10_folds.train_8.predict)=99.86%
# [ 2018-07-30 23:09:26,278][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_0 - 10_folds.train_9.predict)=99.71%
# [ 2018-07-30 23:09:26,502][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_0 - 10_folds.train_cv.predict)=99.86%
# [ 2018-07-30 23:09:26,503][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_0 - 10_folds.test.predict)=100.00%
# [ 2018-07-30 23:09:26,504][cascade_classifier.calc_accuracy] Accuracy(layer_1 - train.classifier_average)=99.86%
# [ 2018-07-30 23:09:26,505][cascade_classifier.calc_accuracy] Accuracy(layer_1 - test.classifier_average)=100.00%
# [ 2018-07-30 23:09:26,507][cascade_classifier.fit_transform] [layer=2] look_indexs=[0], X_cur_train.shape=(6907, 20), X_cur_test.shape=(2961, 20)
# [ 2018-07-30 23:09:27,014][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_0 - 10_folds.train_0.predict)=99.86%
# [ 2018-07-30 23:09:27,742][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_0 - 10_folds.train_1.predict)=100.00%
# [ 2018-07-30 23:09:28,582][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_0 - 10_folds.train_2.predict)=100.00%
# [ 2018-07-30 23:09:29,309][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_0 - 10_folds.train_3.predict)=99.86%
# [ 2018-07-30 23:09:30,032][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_0 - 10_folds.train_4.predict)=99.71%
# [ 2018-07-30 23:09:30,870][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_0 - 10_folds.train_5.predict)=99.57%
# [ 2018-07-30 23:09:31,590][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_0 - 10_folds.train_6.predict)=99.86%
# [ 2018-07-30 23:09:32,311][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_0 - 10_folds.train_7.predict)=99.71%
# [ 2018-07-30 23:09:33,038][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_0 - 10_folds.train_8.predict)=99.86%
# [ 2018-07-30 23:09:33,760][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_0 - 10_folds.train_9.predict)=100.00%
# [ 2018-07-30 23:09:33,981][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_0 - 10_folds.train_cv.predict)=99.84%
# [ 2018-07-30 23:09:33,982][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_0 - 10_folds.test.predict)=100.00%
# [ 2018-07-30 23:09:33,983][cascade_classifier.calc_accuracy] Accuracy(layer_2 - train.classifier_average)=99.84%
# [ 2018-07-30 23:09:33,984][cascade_classifier.calc_accuracy] Accuracy(layer_2 - test.classifier_average)=100.00%
# [ 2018-07-30 23:09:33,986][cascade_classifier.fit_transform] [layer=3] look_indexs=[0], X_cur_train.shape=(6907, 20), X_cur_test.shape=(2961, 20)
# [ 2018-07-30 23:09:34,645][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_0 - 10_folds.train_0.predict)=99.86%
# [ 2018-07-30 23:09:35,485][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_0 - 10_folds.train_1.predict)=100.00%
# [ 2018-07-30 23:09:36,214][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_0 - 10_folds.train_2.predict)=99.86%
# [ 2018-07-30 23:09:37,055][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_0 - 10_folds.train_3.predict)=99.71%
# [ 2018-07-30 23:09:37,891][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_0 - 10_folds.train_4.predict)=99.86%
# [ 2018-07-30 23:09:38,737][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_0 - 10_folds.train_5.predict)=100.00%
# [ 2018-07-30 23:09:39,460][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_0 - 10_folds.train_6.predict)=100.00%
# [ 2018-07-30 23:09:40,188][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_0 - 10_folds.train_7.predict)=100.00%
# [ 2018-07-30 23:09:40,912][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_0 - 10_folds.train_8.predict)=99.86%
# [ 2018-07-30 23:09:41,639][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_0 - 10_folds.train_9.predict)=99.86%
# [ 2018-07-30 23:09:41,864][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_0 - 10_folds.train_cv.predict)=99.90%
# [ 2018-07-30 23:09:41,865][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_0 - 10_folds.test.predict)=100.00%
# [ 2018-07-30 23:09:41,866][cascade_classifier.calc_accuracy] Accuracy(layer_3 - train.classifier_average)=99.90%
# [ 2018-07-30 23:09:41,867][cascade_classifier.calc_accuracy] Accuracy(layer_3 - test.classifier_average)=100.00%
# [ 2018-07-30 23:09:41,868][cascade_classifier.fit_transform] [Result][Optimal Level Detected] opt_layer_num=1, accuracy_train=99.90%, accuracy_test=100.00%
# [ 2018-07-30 23:09:41,872][cascade_classifier.transform] X_groups_test.shape=[(2961, 18)]
# [ 2018-07-30 23:09:41,873][cascade_classifier.transform] group_dims=[18]
# [ 2018-07-30 23:09:41,874][cascade_classifier.transform] X_test.shape=(2961, 18)
# [ 2018-07-30 23:09:41,875][cascade_classifier.transform] [layer=0] look_indexs=[0], X_cur_test.shape=(2961, 18)
# [ 2018-07-30 23:09:43,984][cascade_classifier.fit_transform] X_groups_train.shape=[(6907, 18)],y_train.shape=(6907,),X_groups_test.shape=[(2961, 18)],y_test.shape=(2961,)
# [ 2018-07-30 23:09:43,985][cascade_classifier.fit_transform] group_dims=[18]
# [ 2018-07-30 23:09:43,986][cascade_classifier.fit_transform] group_starts=[0]
# [ 2018-07-30 23:09:43,987][cascade_classifier.fit_transform] group_ends=[18]
# [ 2018-07-30 23:09:43,987][cascade_classifier.fit_transform] X_train.shape=(6907, 18),X_test.shape=(2961, 18)
# [ 2018-07-30 23:09:43,989][cascade_classifier.fit_transform] [layer=0] look_indexs=[0], X_cur_train.shape=(6907, 18), X_cur_test.shape=(2961, 18)
# ('Test Accuracy of CascadeExtraTrees = 100.000000 %', 'Layer :', 3)
# [[2957    0]
#  [   0    4]]
#
#
#              precision    recall  f1-score   support
#
#         0.0       1.00      1.00      1.00      2957
#         1.0       1.00      1.00      1.00         4
#
# avg / total       1.00      1.00      1.00      2961
#
# (' Time ', '31.209', ' seconds')
# [ 2018-07-30 23:09:44,614][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_0.predict)=100.00%
# [ 2018-07-30 23:09:45,457][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_1.predict)=100.00%
# [ 2018-07-30 23:09:46,186][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_2.predict)=99.86%
# [ 2018-07-30 23:09:46,905][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_3.predict)=99.71%
# [ 2018-07-30 23:09:47,667][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_4.predict)=99.86%
# [ 2018-07-30 23:09:48,388][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_5.predict)=100.00%
# [ 2018-07-30 23:09:49,226][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_6.predict)=100.00%
# [ 2018-07-30 23:09:49,951][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_7.predict)=99.71%
# [ 2018-07-30 23:09:50,791][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_8.predict)=100.00%
# [ 2018-07-30 23:09:51,632][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_9.predict)=99.86%
# [ 2018-07-30 23:09:51,859][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_cv.predict)=99.90%
# [ 2018-07-30 23:09:51,860][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.test.predict)=100.00%
# [ 2018-07-30 23:09:51,861][cascade_classifier.calc_accuracy] Accuracy(layer_0 - train.classifier_average)=99.90%
# [ 2018-07-30 23:09:51,862][cascade_classifier.calc_accuracy] Accuracy(layer_0 - test.classifier_average)=100.00%
# [ 2018-07-30 23:09:51,864][cascade_classifier.fit_transform] [layer=1] look_indexs=[0], X_cur_train.shape=(6907, 20), X_cur_test.shape=(2961, 20)
# [ 2018-07-30 23:09:52,486][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_0 - 10_folds.train_0.predict)=99.86%
# [ 2018-07-30 23:09:53,207][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_0 - 10_folds.train_1.predict)=99.86%
# [ 2018-07-30 23:09:53,934][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_0 - 10_folds.train_2.predict)=99.86%
# [ 2018-07-30 23:09:54,659][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_0 - 10_folds.train_3.predict)=100.00%
# [ 2018-07-30 23:09:55,387][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_0 - 10_folds.train_4.predict)=99.86%
# [ 2018-07-30 23:09:56,221][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_0 - 10_folds.train_5.predict)=100.00%
# [ 2018-07-30 23:09:56,946][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_0 - 10_folds.train_6.predict)=99.86%
# [ 2018-07-30 23:09:57,669][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_0 - 10_folds.train_7.predict)=99.71%
# [ 2018-07-30 23:09:58,391][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_0 - 10_folds.train_8.predict)=99.86%
# [ 2018-07-30 23:09:59,150][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_0 - 10_folds.train_9.predict)=99.71%
# [ 2018-07-30 23:09:59,375][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_0 - 10_folds.train_cv.predict)=99.86%
# [ 2018-07-30 23:09:59,376][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_0 - 10_folds.test.predict)=100.00%
# [ 2018-07-30 23:09:59,377][cascade_classifier.calc_accuracy] Accuracy(layer_1 - train.classifier_average)=99.86%
# [ 2018-07-30 23:09:59,378][cascade_classifier.calc_accuracy] Accuracy(layer_1 - test.classifier_average)=100.00%
# [ 2018-07-30 23:09:59,379][cascade_classifier.fit_transform] [layer=2] look_indexs=[0], X_cur_train.shape=(6907, 20), X_cur_test.shape=(2961, 20)
# [ 2018-07-30 23:09:59,889][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_0 - 10_folds.train_0.predict)=99.86%
# [ 2018-07-30 23:10:00,729][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_0 - 10_folds.train_1.predict)=99.86%
# [ 2018-07-30 23:10:01,573][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_0 - 10_folds.train_2.predict)=100.00%
# [ 2018-07-30 23:10:02,414][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_0 - 10_folds.train_3.predict)=99.86%
# [ 2018-07-30 23:10:03,133][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_0 - 10_folds.train_4.predict)=99.71%
# [ 2018-07-30 23:10:03,976][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_0 - 10_folds.train_5.predict)=99.57%
# [ 2018-07-30 23:10:04,819][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_0 - 10_folds.train_6.predict)=99.86%
# [ 2018-07-30 23:10:05,544][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_0 - 10_folds.train_7.predict)=99.71%
# [ 2018-07-30 23:10:06,383][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_0 - 10_folds.train_8.predict)=99.71%
# [ 2018-07-30 23:10:07,110][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_0 - 10_folds.train_9.predict)=100.00%
# [ 2018-07-30 23:10:07,331][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_0 - 10_folds.train_cv.predict)=99.81%
# [ 2018-07-30 23:10:07,332][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_0 - 10_folds.test.predict)=100.00%
# [ 2018-07-30 23:10:07,333][cascade_classifier.calc_accuracy] Accuracy(layer_2 - train.classifier_average)=99.81%
# [ 2018-07-30 23:10:07,334][cascade_classifier.calc_accuracy] Accuracy(layer_2 - test.classifier_average)=100.00%
# [ 2018-07-30 23:10:07,336][cascade_classifier.fit_transform] [layer=3] look_indexs=[0], X_cur_train.shape=(6907, 20), X_cur_test.shape=(2961, 20)
# [ 2018-07-30 23:10:07,840][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_0 - 10_folds.train_0.predict)=100.00%
# [ 2018-07-30 23:10:08,561][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_0 - 10_folds.train_1.predict)=100.00%
# [ 2018-07-30 23:10:09,395][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_0 - 10_folds.train_2.predict)=99.86%
# [ 2018-07-30 23:10:10,117][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_0 - 10_folds.train_3.predict)=99.57%
# [ 2018-07-30 23:10:10,952][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_0 - 10_folds.train_4.predict)=99.86%
# [ 2018-07-30 23:10:11,717][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_0 - 10_folds.train_5.predict)=100.00%
# [ 2018-07-30 23:10:12,439][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_0 - 10_folds.train_6.predict)=100.00%
# [ 2018-07-30 23:10:13,280][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_0 - 10_folds.train_7.predict)=100.00%
# [ 2018-07-30 23:10:14,121][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_0 - 10_folds.train_8.predict)=100.00%
# [ 2018-07-30 23:10:14,849][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_0 - 10_folds.train_9.predict)=99.86%
# [ 2018-07-30 23:10:15,073][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_0 - 10_folds.train_cv.predict)=99.91%
# [ 2018-07-30 23:10:15,074][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_0 - 10_folds.test.predict)=100.00%
# [ 2018-07-30 23:10:15,075][cascade_classifier.calc_accuracy] Accuracy(layer_3 - train.classifier_average)=99.91%
# [ 2018-07-30 23:10:15,076][cascade_classifier.calc_accuracy] Accuracy(layer_3 - test.classifier_average)=100.00%
# [ 2018-07-30 23:10:15,078][cascade_classifier.fit_transform] [layer=4] look_indexs=[0], X_cur_train.shape=(6907, 20), X_cur_test.shape=(2961, 20)
# [ 2018-07-30 23:10:15,699][kfold_wrapper.log_eval_metrics] Accuracy(layer_4 - estimator_0 - 10_folds.train_0.predict)=99.86%
# [ 2018-07-30 23:10:16,553][kfold_wrapper.log_eval_metrics] Accuracy(layer_4 - estimator_0 - 10_folds.train_1.predict)=100.00%
# [ 2018-07-30 23:10:17,292][kfold_wrapper.log_eval_metrics] Accuracy(layer_4 - estimator_0 - 10_folds.train_2.predict)=100.00%
# [ 2018-07-30 23:10:18,021][kfold_wrapper.log_eval_metrics] Accuracy(layer_4 - estimator_0 - 10_folds.train_3.predict)=99.86%
# [ 2018-07-30 23:10:18,913][kfold_wrapper.log_eval_metrics] Accuracy(layer_4 - estimator_0 - 10_folds.train_4.predict)=99.86%
# [ 2018-07-30 23:10:19,785][kfold_wrapper.log_eval_metrics] Accuracy(layer_4 - estimator_0 - 10_folds.train_5.predict)=100.00%
# [ 2018-07-30 23:10:20,805][kfold_wrapper.log_eval_metrics] Accuracy(layer_4 - estimator_0 - 10_folds.train_6.predict)=99.86%
# [ 2018-07-30 23:10:21,723][kfold_wrapper.log_eval_metrics] Accuracy(layer_4 - estimator_0 - 10_folds.train_7.predict)=99.86%
# [ 2018-07-30 23:10:22,811][kfold_wrapper.log_eval_metrics] Accuracy(layer_4 - estimator_0 - 10_folds.train_8.predict)=100.00%
# [ 2018-07-30 23:10:23,922][kfold_wrapper.log_eval_metrics] Accuracy(layer_4 - estimator_0 - 10_folds.train_9.predict)=100.00%
# [ 2018-07-30 23:10:24,174][kfold_wrapper.log_eval_metrics] Accuracy(layer_4 - estimator_0 - 10_folds.train_cv.predict)=99.93%
# [ 2018-07-30 23:10:24,175][kfold_wrapper.log_eval_metrics] Accuracy(layer_4 - estimator_0 - 10_folds.test.predict)=100.00%
# [ 2018-07-30 23:10:24,177][cascade_classifier.calc_accuracy] Accuracy(layer_4 - train.classifier_average)=99.93%
# [ 2018-07-30 23:10:24,178][cascade_classifier.calc_accuracy] Accuracy(layer_4 - test.classifier_average)=100.00%
# [ 2018-07-30 23:10:24,181][cascade_classifier.fit_transform] [layer=5] look_indexs=[0], X_cur_train.shape=(6907, 20), X_cur_test.shape=(2961, 20)
# [ 2018-07-30 23:10:24,854][kfold_wrapper.log_eval_metrics] Accuracy(layer_5 - estimator_0 - 10_folds.train_0.predict)=99.71%
# [ 2018-07-30 23:10:25,719][kfold_wrapper.log_eval_metrics] Accuracy(layer_5 - estimator_0 - 10_folds.train_1.predict)=100.00%
# [ 2018-07-30 23:10:26,432][kfold_wrapper.log_eval_metrics] Accuracy(layer_5 - estimator_0 - 10_folds.train_2.predict)=99.86%
# [ 2018-07-30 23:10:27,270][kfold_wrapper.log_eval_metrics] Accuracy(layer_5 - estimator_0 - 10_folds.train_3.predict)=99.86%
# [ 2018-07-30 23:10:28,115][kfold_wrapper.log_eval_metrics] Accuracy(layer_5 - estimator_0 - 10_folds.train_4.predict)=99.86%
# [ 2018-07-30 23:10:28,835][kfold_wrapper.log_eval_metrics] Accuracy(layer_5 - estimator_0 - 10_folds.train_5.predict)=99.86%
# [ 2018-07-30 23:10:29,564][kfold_wrapper.log_eval_metrics] Accuracy(layer_5 - estimator_0 - 10_folds.train_6.predict)=99.86%
# [ 2018-07-30 23:10:30,405][kfold_wrapper.log_eval_metrics] Accuracy(layer_5 - estimator_0 - 10_folds.train_7.predict)=100.00%
# [ 2018-07-30 23:10:31,126][kfold_wrapper.log_eval_metrics] Accuracy(layer_5 - estimator_0 - 10_folds.train_8.predict)=100.00%
# [ 2018-07-30 23:10:31,856][kfold_wrapper.log_eval_metrics] Accuracy(layer_5 - estimator_0 - 10_folds.train_9.predict)=99.86%
# [ 2018-07-30 23:10:32,090][kfold_wrapper.log_eval_metrics] Accuracy(layer_5 - estimator_0 - 10_folds.train_cv.predict)=99.88%
# [ 2018-07-30 23:10:32,091][kfold_wrapper.log_eval_metrics] Accuracy(layer_5 - estimator_0 - 10_folds.test.predict)=100.00%
# [ 2018-07-30 23:10:32,093][cascade_classifier.calc_accuracy] Accuracy(layer_5 - train.classifier_average)=99.88%
# [ 2018-07-30 23:10:32,094][cascade_classifier.calc_accuracy] Accuracy(layer_5 - test.classifier_average)=100.00%
# [ 2018-07-30 23:10:32,096][cascade_classifier.fit_transform] [layer=6] look_indexs=[0], X_cur_train.shape=(6907, 20), X_cur_test.shape=(2961, 20)
# [ 2018-07-30 23:10:32,706][kfold_wrapper.log_eval_metrics] Accuracy(layer_6 - estimator_0 - 10_folds.train_0.predict)=99.71%
# [ 2018-07-30 23:10:33,556][kfold_wrapper.log_eval_metrics] Accuracy(layer_6 - estimator_0 - 10_folds.train_1.predict)=99.86%
# [ 2018-07-30 23:10:34,399][kfold_wrapper.log_eval_metrics] Accuracy(layer_6 - estimator_0 - 10_folds.train_2.predict)=99.86%
# [ 2018-07-30 23:10:35,124][kfold_wrapper.log_eval_metrics] Accuracy(layer_6 - estimator_0 - 10_folds.train_3.predict)=99.42%
# ...
# [ 2018-07-30 23:19:22,078][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_9.predict)=100.00%
# [ 2018-07-30 23:19:22,427][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_cv.predict)=99.91%
# [ 2018-07-30 23:19:22,428][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.test.predict)=100.00%
# [ 2018-07-30 23:19:22,430][cascade_classifier.calc_accuracy] Accuracy(layer_0 - train.classifier_average)=99.91%
# [ 2018-07-30 23:19:22,431][cascade_classifier.calc_accuracy] Accuracy(layer_0 - test.classifier_average)=100.00%
# [ 2018-07-30 23:19:22,433][cascade_classifier.fit_transform] [layer=1] look_indexs=[0], X_cur_train.shape=(6907, 20), X_cur_test.shape=(2961, 20)
# [ 2018-07-30 23:19:23,382][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_0 - 10_folds.train_0.predict)=99.86%
# [ 2018-07-30 23:19:24,433][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_0 - 10_folds.train_1.predict)=99.86%
# [ 2018-07-30 23:19:25,330][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_0 - 10_folds.train_2.predict)=99.71%
# [ 2018-07-30 23:19:26,056][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_0 - 10_folds.train_3.predict)=100.00%
# [ 2018-07-30 23:19:26,778][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_0 - 10_folds.train_4.predict)=100.00%
# [ 2018-07-30 23:19:27,502][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_0 - 10_folds.train_5.predict)=100.00%
# [ 2018-07-30 23:19:28,229][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_0 - 10_folds.train_6.predict)=100.00%
# [ 2018-07-30 23:19:28,957][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_0 - 10_folds.train_7.predict)=100.00%
# [ 2018-07-30 23:19:29,677][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_0 - 10_folds.train_8.predict)=99.86%
# [ 2018-07-30 23:19:30,402][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_0 - 10_folds.train_9.predict)=99.86%
# [ 2018-07-30 23:19:30,624][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_0 - 10_folds.train_cv.predict)=99.91%
# [ 2018-07-30 23:19:30,625][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_0 - 10_folds.test.predict)=100.00%
# [ 2018-07-30 23:19:30,626][cascade_classifier.calc_accuracy] Accuracy(layer_1 - train.classifier_average)=99.91%
# [ 2018-07-30 23:19:30,627][cascade_classifier.calc_accuracy] Accuracy(layer_1 - test.classifier_average)=100.00%
# [ 2018-07-30 23:19:30,629][cascade_classifier.fit_transform] [layer=2] look_indexs=[0], X_cur_train.shape=(6907, 20), X_cur_test.shape=(2961, 20)
# [ 2018-07-30 23:19:31,134][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_0 - 10_folds.train_0.predict)=100.00%
# [ 2018-07-30 23:19:31,860][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_0 - 10_folds.train_1.predict)=100.00%
# [ 2018-07-30 23:19:32,584][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_0 - 10_folds.train_2.predict)=100.00%
# [ 2018-07-30 23:19:33,193][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_0 - 10_folds.train_3.predict)=100.00%
# [ 2018-07-30 23:19:33,914][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_0 - 10_folds.train_4.predict)=99.71%
# [ 2018-07-30 23:19:34,758][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_0 - 10_folds.train_5.predict)=99.71%
# [ 2018-07-30 23:19:35,372][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_0 - 10_folds.train_6.predict)=100.00%
# [ 2018-07-30 23:19:36,096][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_0 - 10_folds.train_7.predict)=99.86%
# [ 2018-07-30 23:19:36,820][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_0 - 10_folds.train_8.predict)=99.86%
# [ 2018-07-30 23:19:37,544][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_0 - 10_folds.train_9.predict)=100.00%
# [ 2018-07-30 23:19:37,766][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_0 - 10_folds.train_cv.predict)=99.91%
# [ 2018-07-30 23:19:37,767][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_0 - 10_folds.test.predict)=100.00%
# [ 2018-07-30 23:19:37,768][cascade_classifier.calc_accuracy] Accuracy(layer_2 - train.classifier_average)=99.91%
# [ 2018-07-30 23:19:37,769][cascade_classifier.calc_accuracy] Accuracy(layer_2 - test.classifier_average)=100.00%
# [ 2018-07-30 23:19:37,771][cascade_classifier.fit_transform] [layer=3] look_indexs=[0], X_cur_train.shape=(6907, 20), X_cur_test.shape=(2961, 20)
# [ 2018-07-30 23:19:38,275][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_0 - 10_folds.train_0.predict)=99.86%
# [ 2018-07-30 23:19:39,002][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_0 - 10_folds.train_1.predict)=99.71%
# [ 2018-07-30 23:19:39,726][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_0 - 10_folds.train_2.predict)=99.86%
# [ 2018-07-30 23:19:40,448][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_0 - 10_folds.train_3.predict)=99.71%
# [ 2018-07-30 23:19:41,173][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_0 - 10_folds.train_4.predict)=100.00%
# [ 2018-07-30 23:19:42,007][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_0 - 10_folds.train_5.predict)=100.00%
# [ 2018-07-30 23:19:42,729][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_0 - 10_folds.train_6.predict)=100.00%
# [ 2018-07-30 23:19:43,571][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_0 - 10_folds.train_7.predict)=100.00%
# [ 2018-07-30 23:19:44,414][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_0 - 10_folds.train_8.predict)=100.00%
# [ 2018-07-30 23:19:45,142][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_0 - 10_folds.train_9.predict)=100.00%
# [ 2018-07-30 23:19:45,368][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_0 - 10_folds.train_cv.predict)=99.91%
# [ 2018-07-30 23:19:45,369][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_0 - 10_folds.test.predict)=100.00%
# [ 2018-07-30 23:19:45,370][cascade_classifier.calc_accuracy] Accuracy(layer_3 - train.classifier_average)=99.91%
# [ 2018-07-30 23:19:45,371][cascade_classifier.calc_accuracy] Accuracy(layer_3 - test.classifier_average)=100.00%
# [ 2018-07-30 23:19:45,371][cascade_classifier.fit_transform] [Result][Optimal Level Detected] opt_layer_num=1, accuracy_train=99.91%, accuracy_test=100.00%
# [ 2018-07-30 23:19:45,376][cascade_classifier.transform] X_groups_test.shape=[(2961, 18)]
# [ 2018-07-30 23:19:45,377][cascade_classifier.transform] group_dims=[18]
# [ 2018-07-30 23:19:45,378][cascade_classifier.transform] X_test.shape=(2961, 18)
# [ 2018-07-30 23:19:45,379][cascade_classifier.transform] [layer=0] look_indexs=[0], X_cur_test.shape=(2961, 18)
# [ 2018-07-30 23:19:47,607][cascade_classifier.fit_transform] X_groups_train.shape=[(6907, 18)],y_train.shape=(6907,),X_groups_test.shape=[(2961, 18)],y_test.shape=(2961,)
# [ 2018-07-30 23:19:47,609][cascade_classifier.fit_transform] group_dims=[18]
# [ 2018-07-30 23:19:47,610][cascade_classifier.fit_transform] group_starts=[0]
# [ 2018-07-30 23:19:47,610][cascade_classifier.fit_transform] group_ends=[18]
# [ 2018-07-30 23:19:47,611][cascade_classifier.fit_transform] X_train.shape=(6907, 18),X_test.shape=(2961, 18)
# [ 2018-07-30 23:19:47,613][cascade_classifier.fit_transform] [layer=0] look_indexs=[0], X_cur_train.shape=(6907, 18), X_cur_test.shape=(2961, 18)
# ('Test Accuracy of CascadeExtraTrees = 100.000000 %', 'Layer :', 18)
# [[2957    0]
#  [   0    4]]
#
#
#              precision    recall  f1-score   support
#
#         0.0       1.00      1.00      1.00      2957
#         1.0       1.00      1.00      1.00         4
#
# avg / total       1.00      1.00      1.00      2961
#
# (' Time ', '31.455', ' seconds')
# [ 2018-07-30 23:19:48,129][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_0.predict)=100.00%
# [ 2018-07-30 23:19:48,726][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_1.predict)=100.00%
# [ 2018-07-30 23:19:49,449][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_2.predict)=99.86%
# [ 2018-07-30 23:19:50,169][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_3.predict)=99.71%
# [ 2018-07-30 23:19:50,893][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_4.predict)=99.86%
# [ 2018-07-30 23:19:51,735][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_5.predict)=99.86%
# [ 2018-07-30 23:19:52,581][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_6.predict)=100.00%
# [ 2018-07-30 23:19:53,306][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_7.predict)=100.00%
# [ 2018-07-30 23:19:54,035][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_8.predict)=100.00%
# [ 2018-07-30 23:19:54,764][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_9.predict)=100.00%
# [ 2018-07-30 23:19:54,986][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_cv.predict)=99.93%
# [ 2018-07-30 23:19:54,988][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.test.predict)=100.00%
# [ 2018-07-30 23:19:54,989][cascade_classifier.calc_accuracy] Accuracy(layer_0 - train.classifier_average)=99.93%
# [ 2018-07-30 23:19:54,990][cascade_classifier.calc_accuracy] Accuracy(layer_0 - test.classifier_average)=100.00%
# [ 2018-07-30 23:19:54,991][cascade_classifier.fit_transform] [layer=1] look_indexs=[0], X_cur_train.shape=(6907, 20), X_cur_test.shape=(2961, 20)
# [ 2018-07-30 23:19:55,494][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_0 - 10_folds.train_0.predict)=99.86%
# [ 2018-07-30 23:19:56,220][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_0 - 10_folds.train_1.predict)=99.86%
# [ 2018-07-30 23:19:56,947][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_0 - 10_folds.train_2.predict)=99.71%
# [ 2018-07-30 23:19:57,673][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_0 - 10_folds.train_3.predict)=100.00%
# [ 2018-07-30 23:19:58,394][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_0 - 10_folds.train_4.predict)=100.00%
# [ 2018-07-30 23:19:59,235][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_0 - 10_folds.train_5.predict)=100.00%
# [ 2018-07-30 23:19:59,961][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_0 - 10_folds.train_6.predict)=100.00%
# [ 2018-07-30 23:20:00,686][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_0 - 10_folds.train_7.predict)=100.00%
# [ 2018-07-30 23:20:01,454][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_0 - 10_folds.train_8.predict)=99.86%
# [ 2018-07-30 23:20:02,182][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_0 - 10_folds.train_9.predict)=99.71%
# [ 2018-07-30 23:20:02,405][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_0 - 10_folds.train_cv.predict)=99.90%
# [ 2018-07-30 23:20:02,406][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_0 - 10_folds.test.predict)=100.00%
# [ 2018-07-30 23:20:02,408][cascade_classifier.calc_accuracy] Accuracy(layer_1 - train.classifier_average)=99.90%
# [ 2018-07-30 23:20:02,409][cascade_classifier.calc_accuracy] Accuracy(layer_1 - test.classifier_average)=100.00%
# [ 2018-07-30 23:20:02,411][cascade_classifier.fit_transform] [layer=2] look_indexs=[0], X_cur_train.shape=(6907, 20), X_cur_test.shape=(2961, 20)
# [ 2018-07-30 23:20:02,917][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_0 - 10_folds.train_0.predict)=100.00%
# [ 2018-07-30 23:20:03,769][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_0 - 10_folds.train_1.predict)=100.00%
# [ 2018-07-30 23:20:04,510][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_0 - 10_folds.train_2.predict)=100.00%
# [ 2018-07-30 23:20:05,232][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_0 - 10_folds.train_3.predict)=100.00%
# [ 2018-07-30 23:20:05,949][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_0 - 10_folds.train_4.predict)=99.71%
# [ 2018-07-30 23:20:06,672][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_0 - 10_folds.train_5.predict)=99.71%
# [ 2018-07-30 23:20:07,402][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_0 - 10_folds.train_6.predict)=100.00%
# [ 2018-07-30 23:20:08,128][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_0 - 10_folds.train_7.predict)=99.86%
# [ 2018-07-30 23:20:08,854][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_0 - 10_folds.train_8.predict)=99.86%
# [ 2018-07-30 23:20:09,577][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_0 - 10_folds.train_9.predict)=100.00%
# [ 2018-07-30 23:20:09,800][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_0 - 10_folds.train_cv.predict)=99.91%
# [ 2018-07-30 23:20:09,801][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_0 - 10_folds.test.predict)=100.00%
# [ 2018-07-30 23:20:09,802][cascade_classifier.calc_accuracy] Accuracy(layer_2 - train.classifier_average)=99.91%
# [ 2018-07-30 23:20:09,804][cascade_classifier.calc_accuracy] Accuracy(layer_2 - test.classifier_average)=100.00%
# [ 2018-07-30 23:20:09,805][cascade_classifier.fit_transform] [layer=3] look_indexs=[0], X_cur_train.shape=(6907, 20), X_cur_test.shape=(2961, 20)
# [ 2018-07-30 23:20:10,431][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_0 - 10_folds.train_0.predict)=99.86%
# [ 2018-07-30 23:20:11,155][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_0 - 10_folds.train_1.predict)=99.71%
# [ 2018-07-30 23:20:11,763][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_0 - 10_folds.train_2.predict)=99.86%
# [ 2018-07-30 23:20:12,487][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_0 - 10_folds.train_3.predict)=99.71%
# [ 2018-07-30 23:20:13,247][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_0 - 10_folds.train_4.predict)=100.00%
# [ 2018-07-30 23:20:13,969][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_0 - 10_folds.train_5.predict)=100.00%
# [ 2018-07-30 23:20:14,701][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_0 - 10_folds.train_6.predict)=100.00%
# [ 2018-07-30 23:20:15,426][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_0 - 10_folds.train_7.predict)=100.00%
# [ 2018-07-30 23:20:16,152][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_0 - 10_folds.train_8.predict)=100.00%
# [ 2018-07-30 23:20:17,022][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_0 - 10_folds.train_9.predict)=100.00%
# [ 2018-07-30 23:20:17,251][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_0 - 10_folds.train_cv.predict)=99.91%
# [ 2018-07-30 23:20:17,252][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_0 - 10_folds.test.predict)=100.00%
# [ 2018-07-30 23:20:17,254][cascade_classifier.calc_accuracy] Accuracy(layer_3 - train.classifier_average)=99.91%
# [ 2018-07-30 23:20:17,255][cascade_classifier.calc_accuracy] Accuracy(layer_3 - test.classifier_average)=100.00%
# [ 2018-07-30 23:20:17,256][cascade_classifier.fit_transform] [Result][Optimal Level Detected] opt_layer_num=1, accuracy_train=99.93%, accuracy_test=100.00%
# [ 2018-07-30 23:20:17,261][cascade_classifier.transform] X_groups_test.shape=[(2961, 18)]
# [ 2018-07-30 23:20:17,262][cascade_classifier.transform] group_dims=[18]
# [ 2018-07-30 23:20:17,263][cascade_classifier.transform] X_test.shape=(2961, 18)
# [ 2018-07-30 23:20:17,264][cascade_classifier.transform] [layer=0] look_indexs=[0], X_cur_test.shape=(2961, 18)
# ('Test Accuracy of CascadeExtraTrees = 100.000000 %', 'Layer :', 19)
# [[2957    0]
#  [   0    4]]
#
#
#              precision    recall  f1-score   support
#
#         0.0       1.00      1.00      1.00      2957
#         1.0       1.00      1.00      1.00         4
#
# avg / total       1.00      1.00      1.00      2961
#
# (' Time ', '29.656', ' seconds')

# %%
print ("Opt_Cascade_num =",Accuracy.index(max(Accuracy)), " Accuracy =", max(Accuracy) ,
       "Time =" , np.sum(t[0:Accuracy.index(max(Accuracy))+1]))

import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
figure(figsize=(8, 6), dpi=100)
plt.plot(Accuracy, '-o', ms=20, lw=2, alpha=0.7, mfc='orange')
plt.ylabel('Accuracy')
plt.xlabel('Cascade numbers')
plt.show()
# Out:
# ('Opt_Cascade_num =', 0, ' Accuracy =', 100.0, 'Time =', 32.700000000000003)

# %%
Accuracy
# Out:
# [100.0,
#  100.0,
#  100.0,
#  100.0,
#  100.0,
#  100.0,
#  100.0,
#  100.0,
#  100.0,
#  100.0,
#  100.0,
#  100.0,
#  99.97,
#  99.97,
#  99.97,
#  99.97,
#  99.97,
#  100.0,
#  100.0,
#  100.0]
