# %%
#  imports 
import numpy as np
import pandas as pd
from math import sqrt 
from pprint import pprint
from numpy import array
from time import time

# %%
# load data
from keras.datasets import imdb
from keras.preprocessing import sequence
top_words = 5000
(X_train, y_train), (X_test, y_test) = imdb.load_data(num_words=top_words)
max_review_length = 500
X_train = sequence.pad_sequences(X_train, maxlen=max_review_length)
X_test = sequence.pad_sequences(X_test, maxlen=max_review_length)
# Out:
# Using TensorFlow backend.

# %%
X_train.shape
# Out:
# (25000, 500)

# %%
X_test.shape
# Out:
# (25000, 500)

# %%
# CascadeExtraTrees
import argparse
import numpy as np
import sys
import pickle
from sklearn.metrics import accuracy_score
sys.path.insert(0, "lib")
from gcforest.gcforest import GCForest
from gcforest.utils.config_utils import load_json
config = load_json("./examples/imbd.json")  
gc = GCForest(config)

# %%
# count class
len(np.unique(y_train))
# Out:
# 2

# %%
  # X_enc is the concatenated predict_proba result of CascadeExtraTrees   
X_train_enc, X_test_enc = gc.fit_transform(X_train, y_train, X_test=X_test, y_test=y_test)
# Out:
# [ 2018-07-30 18:47:41,196][cascade_classifier.fit_transform] X_groups_train.shape=[(25000, 500)],y_train.shape=(25000,),X_groups_test.shape=[(25000, 500)],y_test.shape=(25000,)
# [ 2018-07-30 18:47:41,224][cascade_classifier.fit_transform] group_dims=[500]
# [ 2018-07-30 18:47:41,225][cascade_classifier.fit_transform] group_starts=[0]
# [ 2018-07-30 18:47:41,226][cascade_classifier.fit_transform] group_ends=[500]
# [ 2018-07-30 18:47:41,227][cascade_classifier.fit_transform] X_train.shape=(25000, 500),X_test.shape=(25000, 500)
# [ 2018-07-30 18:47:41,292][cascade_classifier.fit_transform] [layer=0] look_indexs=[0], X_cur_train.shape=(25000, 500), X_cur_test.shape=(25000, 500)
# [ 2018-07-30 18:47:45,150][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_0.predict)=52.04%
# [ 2018-07-30 18:47:49,345][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_1.predict)=52.36%
# [ 2018-07-30 18:47:53,642][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_2.predict)=53.08%
# [ 2018-07-30 18:47:57,742][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_3.predict)=52.48%
# [ 2018-07-30 18:48:02,468][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_4.predict)=51.48%
# [ 2018-07-30 18:48:07,170][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_5.predict)=53.28%
# [ 2018-07-30 18:48:11,341][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_6.predict)=52.68%
# [ 2018-07-30 18:48:15,525][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_7.predict)=53.16%
# [ 2018-07-30 18:48:19,651][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_8.predict)=51.16%
# [ 2018-07-30 18:48:23,942][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_9.predict)=52.60%
# [ 2018-07-30 18:48:24,329][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_cv.predict)=52.43%
# [ 2018-07-30 18:48:24,330][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.test.predict)=52.65%
# [ 2018-07-30 18:48:24,332][cascade_classifier.calc_accuracy] Accuracy(layer_0 - train.classifier_average)=52.43%
# [ 2018-07-30 18:48:24,333][cascade_classifier.calc_accuracy] Accuracy(layer_0 - test.classifier_average)=52.65%
# [ 2018-07-30 18:48:24,334][cascade_classifier.fit_transform] [Result][Reach Max Layer] opt_layer_num=1, accuracy_train=52.43%, accuracy_test=52.65%

# %%
# predict
y_pred = gc.predict(X_test)
acc = accuracy_score(y_test, y_pred)
print("Test Accuracy of CascadeExtraTrees = {:.6f} %".format(acc * 100))
 # Matrix de confusion
from sklearn.metrics import classification_report, confusion_matrix
print(confusion_matrix(y_test,y_pred))
print('\n')
print(classification_report(y_test,y_pred))
# Out:
# [ 2018-07-30 18:48:24,343][cascade_classifier.transform] X_groups_test.shape=[(25000, 500)]
# [ 2018-07-30 18:48:24,350][cascade_classifier.transform] group_dims=[500]
# [ 2018-07-30 18:48:24,351][cascade_classifier.transform] X_test.shape=(25000, 500)
# [ 2018-07-30 18:48:24,384][cascade_classifier.transform] [layer=0] look_indexs=[0], X_cur_test.shape=(25000, 500)
# Test Accuracy of CascadeExtraTrees = 52.656000 %
# [[7193 5307]
#  [6529 5971]]
#
#
#              precision    recall  f1-score   support
#
#           0       0.52      0.58      0.55     12500
#           1       0.53      0.48      0.50     12500
#
# avg / total       0.53      0.53      0.53     25000

# %%
# predict_proba result of CascadeExtraTrees + data

X_test_enc = gc.transform(X_test)
X_train_enc = X_train_enc.reshape((X_train_enc.shape[0], -1))
X_test_enc = X_test_enc.reshape((X_test_enc.shape[0], -1))
X_train_origin = X_train.reshape((X_train.shape[0], -1))
X_test_origin = X_test.reshape((X_test.shape[0], -1))
X_train_enc = np.hstack((X_train_origin, X_train_enc))
X_test_enc = np.hstack((X_test_origin, X_test_enc))
# Out:
# [ 2018-07-30 18:48:28,172][cascade_classifier.transform] X_groups_test.shape=[(25000, 500)]
# [ 2018-07-30 18:48:28,180][cascade_classifier.transform] group_dims=[500]
# [ 2018-07-30 18:48:28,181][cascade_classifier.transform] X_test.shape=(25000, 500)
# [ 2018-07-30 18:48:28,214][cascade_classifier.transform] [layer=0] look_indexs=[0], X_cur_test.shape=(25000, 500)

# %%
X_test_enc.shape
# Out:
# (25000, 502)

# %%
X_train_new = X_train_enc
X_test_new  = X_test_enc

# %%
X_train_new.shape
# Out:
# (25000, 502)

# %%
# Casacade ExtraTrees
config = load_json("./examples/imbdgc.json")  
gc = GCForest(config)

X_train=X_train_enc
X_test=X_test_enc 
X_train_enc, X_test_enc = gc.fit_transform(X_train, y_train, X_test=X_test, y_test=y_test)
# Out:
# [ 2018-07-30 18:48:32,106][cascade_classifier.fit_transform] X_groups_train.shape=[(25000, 502)],y_train.shape=(25000,),X_groups_test.shape=[(25000, 502)],y_test.shape=(25000,)
# [ 2018-07-30 18:48:32,183][cascade_classifier.fit_transform] group_dims=[502]
# [ 2018-07-30 18:48:32,184][cascade_classifier.fit_transform] group_starts=[0]
# [ 2018-07-30 18:48:32,184][cascade_classifier.fit_transform] group_ends=[502]
# [ 2018-07-30 18:48:32,185][cascade_classifier.fit_transform] X_train.shape=(25000, 502),X_test.shape=(25000, 502)
# [ 2018-07-30 18:48:32,261][cascade_classifier.fit_transform] [layer=0] look_indexs=[0], X_cur_train.shape=(25000, 502), X_cur_test.shape=(25000, 502)
# [ 2018-07-30 18:48:38,066][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_0.predict)=53.28%
# [ 2018-07-30 18:48:44,236][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_1.predict)=52.32%
# [ 2018-07-30 18:48:50,502][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_2.predict)=50.56%
# [ 2018-07-30 18:48:56,812][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_3.predict)=51.92%
# [ 2018-07-30 18:49:03,578][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_4.predict)=52.68%
# [ 2018-07-30 18:49:10,598][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_5.predict)=52.72%
# [ 2018-07-30 18:49:16,978][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_6.predict)=52.64%
# [ 2018-07-30 18:49:23,757][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_7.predict)=51.96%
# [ 2018-07-30 18:49:31,651][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_8.predict)=51.40%
# [ 2018-07-30 18:49:38,111][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_9.predict)=52.68%
# [ 2018-07-30 18:49:38,460][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_cv.predict)=52.22%
# [ 2018-07-30 18:49:38,461][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.test.predict)=53.08%
# [ 2018-07-30 18:49:38,463][cascade_classifier.calc_accuracy] Accuracy(layer_0 - train.classifier_average)=52.22%
# [ 2018-07-30 18:49:38,464][cascade_classifier.calc_accuracy] Accuracy(layer_0 - test.classifier_average)=53.08%
# [ 2018-07-30 18:49:38,556][cascade_classifier.fit_transform] [layer=1] look_indexs=[0], X_cur_train.shape=(25000, 504), X_cur_test.shape=(25000, 504)
# [ 2018-07-30 18:49:42,390][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_0 - 10_folds.train_0.predict)=52.32%
# [ 2018-07-30 18:49:46,717][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_0 - 10_folds.train_1.predict)=52.16%
# [ 2018-07-30 18:49:50,865][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_0 - 10_folds.train_2.predict)=51.80%
# [ 2018-07-30 18:49:55,539][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_0 - 10_folds.train_3.predict)=52.60%
# [ 2018-07-30 18:50:03,851][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_0 - 10_folds.train_4.predict)=53.00%
# [ 2018-07-30 18:50:08,430][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_0 - 10_folds.train_5.predict)=50.32%
# [ 2018-07-30 18:50:12,731][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_0 - 10_folds.train_6.predict)=55.40%
# [ 2018-07-30 18:50:16,990][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_0 - 10_folds.train_7.predict)=51.92%
# [ 2018-07-30 18:50:21,294][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_0 - 10_folds.train_8.predict)=52.36%
# [ 2018-07-30 18:50:26,875][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_0 - 10_folds.train_9.predict)=51.72%
# [ 2018-07-30 18:50:27,223][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_0 - 10_folds.train_cv.predict)=52.36%
# [ 2018-07-30 18:50:27,224][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_0 - 10_folds.test.predict)=53.12%
# [ 2018-07-30 18:50:27,227][cascade_classifier.calc_accuracy] Accuracy(layer_1 - train.classifier_average)=52.36%
# [ 2018-07-30 18:50:27,229][cascade_classifier.calc_accuracy] Accuracy(layer_1 - test.classifier_average)=53.12%
# [ 2018-07-30 18:50:27,323][cascade_classifier.fit_transform] [layer=2] look_indexs=[0], X_cur_train.shape=(25000, 504), X_cur_test.shape=(25000, 504)
# [ 2018-07-30 18:50:31,147][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_0 - 10_folds.train_0.predict)=52.88%
# [ 2018-07-30 18:50:35,328][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_0 - 10_folds.train_1.predict)=51.68%
# [ 2018-07-30 18:50:39,476][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_0 - 10_folds.train_2.predict)=51.80%
# [ 2018-07-30 18:50:43,679][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_0 - 10_folds.train_3.predict)=53.76%
# [ 2018-07-30 18:50:49,324][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_0 - 10_folds.train_4.predict)=50.68%
# [ 2018-07-30 18:50:54,043][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_0 - 10_folds.train_5.predict)=53.24%
# [ 2018-07-30 18:50:58,266][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_0 - 10_folds.train_6.predict)=52.20%
# [ 2018-07-30 18:51:02,818][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_0 - 10_folds.train_7.predict)=53.48%
# [ 2018-07-30 18:51:07,104][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_0 - 10_folds.train_8.predict)=53.08%
# [ 2018-07-30 18:51:12,808][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_0 - 10_folds.train_9.predict)
kfold_wrapper.log_eval_metrics] Accuracy(layer_6 - estimator_0 - 10_folds.train_cv.predict)=51.90%
# [ 2018-07-30 18:54:15,937][kfold_wrapper.log_eval_metrics] Accuracy(layer_6 - estimator_0 - 10_folds.test.predict)=53.04%
# [ 2018-07-30 18:54:15,938][cascade_classifier.calc_accuracy] Accuracy(layer_6 - train.classifier_average)=51.90%
# [ 2018-07-30 18:54:15,939][cascade_classifier.calc_accuracy] Accuracy(layer_6 - test.classifier_average)=53.04%
# [ 2018-07-30 18:54:15,940][cascade_classifier.fit_transform] [Result][Optimal Level Detected] opt_layer_num=4, accuracy_train=52.78%, accuracy_test=52.94%

# %%
y_pred = gc.predict(X_test)
acc = accuracy_score(y_test, y_pred)
print("Test Accuracy of CascadeExtraTrees = {:.6f} %".format(acc * 100))
 # Matrix de confusion
from sklearn.metrics import classification_report, confusion_matrix
print(confusion_matrix(y_test,y_pred))
print('\n')
print(classification_report(y_test,y_pred))
# Out:
# [ 2018-07-30 18:54:16,066][cascade_classifier.transform] X_groups_test.shape=[(25000, 502)]
# [ 2018-07-30 18:54:16,106][cascade_classifier.transform] group_dims=[502]
# [ 2018-07-30 18:54:16,107][cascade_classifier.transform] X_test.shape=(25000, 502)
# [ 2018-07-30 18:54:16,147][cascade_classifier.transform] [layer=0] look_indexs=[0], X_cur_test.shape=(25000, 502)
# [ 2018-07-30 18:54:19,904][cascade_classifier.transform] [layer=1] look_indexs=[0], X_cur_test.shape=(25000, 504)
# [ 2018-07-30 18:54:23,658][cascade_classifier.transform] [layer=2] look_indexs=[0], X_cur_test.shape=(25000, 504)
# [ 2018-07-30 18:54:27,400][cascade_classifier.transform] [layer=3] look_indexs=[0], X_cur_test.shape=(25000, 504)
# Test Accuracy of CascadeExtraTrees = 52.924000 %
# [[7302 5198]
#  [6571 5929]]
#
#
#              precision    recall  f1-score   support
#
#           0       0.53      0.58      0.55     12500
#           1       0.53      0.47      0.50     12500
#
# avg / total       0.53      0.53      0.53     25000

# %%
# CascadeExtraTrees
def update(X_train,X_test):
    # update Estimators
    M = np.delete(X_train, (-1), axis=1)
    X_train= np.delete(M, (-1), axis=1)
    M = np.delete(X_test, (-1), axis=1)
    X_test = np.delete(M, (-1), axis=1)
    return X_train,X_test

def newdata(X_test_enc, X_train_enc):
    # Make Data + Estimators
    X_train_origin = X_train.reshape((X_train.shape[0], -1))
    X_test_origin = X_test.reshape((X_test.shape[0], -1))
    X_train_enc = np.hstack((X_train_origin, X_train_enc))
    X_test_enc = np.hstack((X_test_origin, X_test_enc))
    return X_test_enc, X_train_enc

Accuracy = []
def affiche():
    # predict
    y_pred = gc.predict(X_test)
    acc = accuracy_score(y_test, y_pred)
    print("Test Accuracy of CascadeExtraTrees = {:.6f} %".format(acc * 100),"Layer :",i)
    Accuracy.append(round(acc*100 , 2))
    # Matrix de confusion
    from sklearn.metrics import classification_report, confusion_matrix
    print(confusion_matrix(y_test,y_pred))
    print('\n')
    print(classification_report(y_test,y_pred))   
    
    
# Deep
t = []
for i in range (20):
    t0 = time()
    X_train,X_test=update(X_train,X_test)
    X_test_enc, X_train_enc=newdata(X_test_enc, X_train_enc)

    X_train=X_train_enc
    X_test=X_test_enc 
    
    config = load_json("./examples/imbdgc.json")  
    gc = GCForest(config)
    X_train_enc, X_test_enc = gc.fit_transform(X_train, y_train, X_test=X_test, y_test=y_test) 
    tt = time() - t0
    affiche() 
    t.append(round(tt,2))
    print (" Time ",format(round(tt,3))," seconds")
# Out:
# [ 2018-07-30 18:54:31,679][cascade_classifier.fit_transform] X_groups_train.shape=[(25000, 502)],y_train.shape=(25000,),X_groups_test.shape=[(25000, 502)],y_test.shape=(25000,)
# [ 2018-07-30 18:54:31,763][cascade_classifier.fit_transform] group_dims=[502]
# [ 2018-07-30 18:54:31,763][cascade_classifier.fit_transform] group_starts=[0]
# [ 2018-07-30 18:54:31,764][cascade_classifier.fit_transform] group_ends=[502]
# [ 2018-07-30 18:54:31,765][cascade_classifier.fit_transform] X_train.shape=(25000, 502),X_test.shape=(25000, 502)
# [ 2018-07-30 18:54:31,844][cascade_classifier.fit_transform] [layer=0] look_indexs=[0], X_cur_train.shape=(25000, 502), X_cur_test.shape=(25000, 502)
# [ 2018-07-30 18:54:37,748][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_0.predict)=53.16%
# [ 2018-07-30 18:54:44,205][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_1.predict)=52.88%
# [ 2018-07-30 18:54:50,638][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_2.predict)=50.24%
# [ 2018-07-30 18:54:56,780][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_3.predict)=51.96%
# [ 2018-07-30 18:55:06,592][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_4.predict)=52.24%
# [ 2018-07-30 18:55:13,807][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_5.predict)=52.40%
# [ 2018-07-30 18:55:20,066][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_6.predict)=52.56%
# [ 2018-07-30 18:55:28,162][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_7.predict)=52.28%
# [ 2018-07-30 18:55:36,627][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_8.predict)=52.76%
# [ 2018-07-30 18:55:42,987][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_9.predict)=53.28%
# [ 2018-07-30 18:55:43,374][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_cv.predict)=52.38%
# [ 2018-07-30 18:55:43,376][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.test.predict)
kfold_wrapper.log_eval_metrics] Accuracy(layer_8 - estimator_0 - 10_folds.train_5.predict)=50.80%
# [ 2018-07-30 19:01:37,919][kfold_wrapper.log_eval_metrics] Accuracy(layer_8 - estimator_0 - 10_folds.train_6.predict)=52.20%
# [ 2018-07-30 19:01:42,176][kfold_wrapper.log_eval_metrics] Accuracy(layer_8 - estimator_0 - 10_folds.train_7.predict)=50.64%
# [ 2018-07-30 19:01:46,637][kfold_wrapper.log_eval_metrics] Accuracy(layer_8 - estimator_0 - 10_folds.train_8.predict)=51.08%
# [ 2018-07-30 19:01:52,324][kfold_wrapper.log_eval_metrics] Accuracy(layer_8 - estimator_0 - 10_folds.train_9.predict)=52.36%
# [ 2018-07-30 19:01:52,669][kfold_wrapper.log_eval_metrics] Accuracy(layer_8 - estimator_0 - 10_folds.train_cv.predict)=51.68%
# [ 2018-07-30 19:01:52,671][kfold_wrapper.log_eval_metrics] Accuracy(layer_8 - estimator_0 - 10_folds.test.predict)=53.06%
# [ 2018-07-30 19:01:52,673][cascade_classifier.calc_accuracy] Accuracy(layer_8 - train.classifier_average)=51.68%
# [ 2018-07-30 19:01:52,674][cascade_classifier.calc_accuracy] Accuracy(layer_8 - test.classifier_average)=53.06%
# [ 2018-07-30 19:01:52,675][cascade_classifier.fit_transform] [Result][Optimal Level Detected] opt_layer_num=6, accuracy_train=52.57%, accuracy_test=53.25%
# [ 2018-07-30 19:01:52,810][cascade_classifier.transform] X_groups_test.shape=[(25000, 502)]
# [ 2018-07-30 19:01:52,851][cascade_classifier.transform] group_dims=[502]
# [ 2018-07-30 19:01:52,852][cascade_classifier.transform] X_test.shape=(25000, 502)
# [ 2018-07-30 19:01:52,892][cascade_classifier.transform] [layer=0] look_indexs=[0], X_cur_test.shape=(25000, 502)
# [ 2018-07-30 19:01:56,711][cascade_classifier.transform] [layer=1] look_indexs=[0], X_cur_test.shape=(25000, 504)
# [ 2018-07-30 19:02:00,411][cascade_classifier.transform] [layer=2] look_indexs=[0], X_cur_test.shape=(25000, 504)
# [ 2018-07-30 19:02:04,256][cascade_classifier.transform] [layer=3] look_indexs=[0], X_cur_test.shape=(25000, 504)
# [ 2018-07-30 19:02:08,212][cascade_classifier.transform] [layer=4] look_indexs=[0], X_cur_test.shape=(25000, 504)
# [ 2018-07-30 19:02:13,349][cascade_classifier.transform] [layer=5] look_indexs=[0], X_cur_test.shape=(25000, 504)
# ('Test Accuracy of CascadeExtraTrees = 53.232000 %', 'Layer :', 0)
# [[7193 5307]
#  [6385 6115]]
#
#
#              precision    recall  f1-score   support
#
#           0       0.53      0.58      0.55     12500
#           1       0.54      0.49      0.51     12500
#
# avg / total       0.53      0.53      0.53     25000
#
# (' Time ', '441.503', ' seconds')
# [ 2018-07-30 19:02:17,589][cascade_classifier.fit_transform] X_groups_train.shape=[(25000, 502)],y_train.shape=(25000,),X_groups_test.shape=[(25000, 502)],y_test.shape=(25000,)
# [ 2018-07-30 19:02:17,671][cascade_classifier.fit_transform] group_dims=[502]
# [ 2018-07-30 19:02:17,672][cascade_classifier.fit_transform] group_starts=[0]
# [ 2018-07-30 19:02:17,673][cascade_classifier.fit_transform] group_ends=[502]
# [ 2018-07-30 19:02:17,674][cascade_classifier.fit_transform] X_train.shape=(25000, 502),X_test.shape=(25000, 502)
# [ 2018-07-30 19:02:17,758][cascade_classifier.fit_transform] [layer=0] look_indexs=[0], X_cur_train.shape=(25000, 502), X_cur_test.shape=(25000, 502)
# [ 2018-07-30 19:02:25,494][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_0.predict)=52.80%
# [ 2018-07-30 19:02:32,973][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_1.predict)=54.44%
# [ 2018-07-30 19:02:39,322][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_2.predict)=51.60%
# [ 2018-07-30 19:02:45,708][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_3.predict)=50.40%
# [ 2018-07-30 19:02:51,889][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_4.predict)=52.52%
# [ 2018-07-30 19:02:58,175][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_5.predict)=52.40%
# [ 2018-07-30 19:03:04,858][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_6.predict)=51.88%
# [ 2018-07-30 19:03:12,000][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_7.predict)=52.52%
# [ 2018-07-30 19:03:18,253][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_8.predict)=51.68%
# [ 2018-07-30 19:03:24,741][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_9.predict)=52.40%
# [ 2018-07-30 19:03:25,127][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_cv.predict)=52.26%
# [ 2018-07-30 19:03:25,129][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.test.predict)=52.81%
# [ 2018-07-30 19:03:25,130][cascade_classifier.calc_accuracy] Accuracy(layer_0 - train.classifier_average)=52.26%
# [ 2018-07-30 19:03:25,131][cascade_classifier.calc_accuracy] Accuracy(layer_0 - test.classifier_average)=52.81%
# [ 2018-07-30 19:03:25,224][cascade_classifier.fit_transform] [layer=1] look_indexs=[0], X_cur_train.shape=(25000, 504), X_cur_test.shape=(25000, 504)
# [ 2018-07-30 19:03:29,045][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_0 - 10_folds.train_0.predict)=50.00%
# [ 2018-07-30 19:03:33,220][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_0 - 10_folds.train_1.predict)=53.00%
# [ 2018-07-30 19:03:37,434][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_0 - 10_folds.train_2.predict)=51.52%
# [ 2018-07-30 19:03:41,617][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_0 - 10_folds.train_3.predict)=52.52%
# [ 2018-07-30 19:03:45,806][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_0 - 10_folds.train_4.predict)=51.24%
# [ 2018-07-30 19:03:49,992][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_0 - 10_folds.train_5.predict)=52.28%
# [ 2018-07-30 19:03:54,171][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_0 - 10_folds.train_6.predict)=51.52%
# [ 2018-07-30 19:03:58,329][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_0 - 10_folds.train_7.predict)=53.48%
# [ 2018-07-30 19:04:02,831][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_0 - 10_folds.train_8.predict)=52.60%
# [ 2018-07-30 19:04:07,505][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_0 - 10_folds.train_9.predict)=52.20%
# [ 2018-07-30 19:04:07,860][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_0 - 10_folds.train_cv.predict)=52.04%
# [ 2018-07-30 19:04:07,862][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_0 - 10_folds.test.predict)=52.92%
# [ 2018-07-30 19:04:07,863][cascade_classifier.calc_accuracy] Accuracy(layer_1 - train.classifier_average)
kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_0 - 10_folds.train_0.predict)=51.56%
# [ 2018-07-30 19:12:44,459][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_0 - 10_folds.train_1.predict)=50.60%
# [ 2018-07-30 19:12:49,189][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_0 - 10_folds.train_2.predict)=53.16%
# [ 2018-07-30 19:12:53,258][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_0 - 10_folds.train_3.predict)=51.44%
# [ 2018-07-30 19:12:57,455][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_0 - 10_folds.train_4.predict)=52.28%
# [ 2018-07-30 19:13:01,649][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_0 - 10_folds.train_5.predict)=52.52%
# [ 2018-07-30 19:13:06,328][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_0 - 10_folds.train_6.predict)=51.08%
# [ 2018-07-30 19:13:11,143][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_0 - 10_folds.train_7.predict)=51.52%
# [ 2018-07-30 19:13:15,356][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_0 - 10_folds.train_8.predict)=52.28%
# [ 2018-07-30 19:13:19,554][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_0 - 10_folds.train_9.predict)=51.56%
# [ 2018-07-30 19:13:19,939][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_0 - 10_folds.train_cv.predict)=51.80%
# [ 2018-07-30 19:13:19,941][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_0 - 10_folds.test.predict)=53.05%
# [ 2018-07-30 19:13:19,942][cascade_classifier.calc_accuracy] Accuracy(layer_2 - train.classifier_average)=51.80%
# [ 2018-07-30 19:13:19,944][cascade_classifier.calc_accuracy] Accuracy(layer_2 - test.classifier_average)=53.05%
# [ 2018-07-30 19:13:20,035][cascade_classifier.fit_transform] [layer=3] look_indexs=[0], X_cur_train.shape=(25000, 504), X_cur_test.shape=(25000, 504)
# [ 2018-07-30 19:13:24,640][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_0 - 10_folds.train_0.predict)=51.24%
# [ 2018-07-30 19:13:30,507][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_0 - 10_folds.train_1.predict)=51.64%
# [ 2018-07-30 19:13:34,585][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_0 - 10_folds.train_2.predict)=52.32%
# [ 2018-07-30 19:13:38,656][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_0 - 10_folds.train_3.predict)=51.76%
# [ 2018-07-30 19:13:42,935][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_0 - 10_folds.train_4.predict)=51.24%
# [ 2018-07-30 19:13:47,156][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_0 - 10_folds.train_5.predict)=51.92%
# [ 2018-07-30 19:13:51,348][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_0 - 10_folds.train_6.predict)=52.52%
# [ 2018-07-30 19:13:55,432][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_0 - 10_folds.train_7.predict)=52.96%
# [ 2018-07-30 19:13:59,755][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_0 - 10_folds.train_8.predict)=53.88%
# ...
# [ 2018-07-30 20:18:44,421][cascade_classifier.calc_accuracy] Accuracy(layer_3 - train.classifier_average)=52.36%
# [ 2018-07-30 20:18:44,422][cascade_classifier.calc_accuracy] Accuracy(layer_3 - test.classifier_average)=53.11%
# [ 2018-07-30 20:18:44,423][cascade_classifier.fit_transform] [Result][Optimal Level Detected] opt_layer_num=1, accuracy_train=52.50%, accuracy_test=52.81%
# [ 2018-07-30 20:18:44,572][cascade_classifier.transform] X_groups_test.shape=[(25000, 502)]
# [ 2018-07-30 20:18:44,611][cascade_classifier.transform] group_dims=[502]
# [ 2018-07-30 20:18:44,612][cascade_classifier.transform] X_test.shape=(25000, 502)
# [ 2018-07-30 20:18:44,650][cascade_classifier.transform] [layer=0] look_indexs=[0], X_cur_test.shape=(25000, 502)
# ('Test Accuracy of CascadeExtraTrees = 52.800000 %', 'Layer :', 18)
# [[7139 5361]
#  [6439 6061]]
#
#
#              precision    recall  f1-score   support
#
#           0       0.53      0.57      0.55     12500
#           1       0.53      0.48      0.51     12500
#
# avg / total       0.53      0.53      0.53     25000
#
# (' Time ', '172.837', ' seconds')
# [ 2018-07-30 20:18:48,657][cascade_classifier.fit_transform] X_groups_train.shape=[(25000, 502)],y_train.shape=(25000,),X_groups_test.shape=[(25000, 502)],y_test.shape=(25000,)
# [ 2018-07-30 20:18:48,733][cascade_classifier.fit_transform] group_dims=[502]
# [ 2018-07-30 20:18:48,734][cascade_classifier.fit_transform] group_starts=[0]
# [ 2018-07-30 20:18:48,735][cascade_classifier.fit_transform] group_ends=[502]
# [ 2018-07-30 20:18:48,736][cascade_classifier.fit_transform] X_train.shape=(25000, 502),X_test.shape=(25000, 502)
# [ 2018-07-30 20:18:48,812][cascade_classifier.fit_transform] [layer=0] look_indexs=[0], X_cur_train.shape=(25000, 502), X_cur_test.shape=(25000, 502)
# [ 2018-07-30 20:18:52,622][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_0.predict)=53.36%
# [ 2018-07-30 20:18:56,824][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_1.predict)=51.32%
# [ 2018-07-30 20:19:01,001][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_2.predict)=51.72%
# [ 2018-07-30 20:19:05,165][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_3.predict)=51.88%
# [ 2018-07-30 20:19:09,344][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_4.predict)=53.12%
# [ 2018-07-30 20:19:13,499][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_5.predict)=53.20%
# [ 2018-07-30 20:19:18,045][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_6.predict)=51.28%
# [ 2018-07-30 20:19:22,887][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_7.predict)=52.24%
# [ 2018-07-30 20:19:29,127][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_8.predict)=51.92%
# [ 2018-07-30 20:19:33,394][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_9.predict)=52.00%
# [ 2018-07-30 20:19:33,779][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.train_cv.predict)=52.20%
# [ 2018-07-30 20:19:33,781][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 10_folds.test.predict)=52.86%
# [ 2018-07-30 20:19:33,782][cascade_classifier.calc_accuracy] Accuracy(layer_0 - train.classifier_average)=52.20%
# [ 2018-07-30 20:19:33,783][cascade_classifier.calc_accuracy] Accuracy(layer_0 - test.classifier_average)=52.86%
# [ 2018-07-30 20:19:33,875][cascade_classifier.fit_transform] [layer=1] look_indexs=[0], X_cur_train.shape=(25000, 504), X_cur_test.shape=(25000, 504)
# [ 2018-07-30 20:19:37,703][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_0 - 10_folds.train_0.predict)=53.16%
# [ 2018-07-30 20:19:41,895][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_0 - 10_folds.train_1.predict)=51.64%
# [ 2018-07-30 20:19:45,976][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_0 - 10_folds.train_2.predict)=52.80%
# [ 2018-07-30 20:19:50,131][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_0 - 10_folds.train_3.predict)=50.96%
# [ 2018-07-30 20:19:54,177][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_0 - 10_folds.train_4.predict)=51.48%
# [ 2018-07-30 20:19:58,391][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_0 - 10_folds.train_5.predict)=52.92%
# [ 2018-07-30 20:20:02,806][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_0 - 10_folds.train_6.predict)=51.08%
# [ 2018-07-30 20:20:06,984][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_0 - 10_folds.train_7.predict)=50.84%
# [ 2018-07-30 20:20:11,165][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_0 - 10_folds.train_8.predict)=51.24%
# [ 2018-07-30 20:20:15,474][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_0 - 10_folds.train_9.predict)=53.36%
# [ 2018-07-30 20:20:15,832][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_0 - 10_folds.train_cv.predict)=51.95%
# [ 2018-07-30 20:20:15,834][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_0 - 10_folds.test.predict)=52.60%
# [ 2018-07-30 20:20:15,836][cascade_classifier.calc_accuracy] Accuracy(layer_1 - train.classifier_average)=51.95%
# [ 2018-07-30 20:20:15,838][cascade_classifier.calc_accuracy] Accuracy(layer_1 - test.classifier_average)=52.60%
# [ 2018-07-30 20:20:15,932][cascade_classifier.fit_transform] [layer=2] look_indexs=[0], X_cur_train.shape=(25000, 504), X_cur_test.shape=(25000, 504)
# [ 2018-07-30 20:20:20,259][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_0 - 10_folds.train_0.predict)=50.40%
# [ 2018-07-30 20:20:24,911][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_0 - 10_folds.train_1.predict)=51.04%
# [ 2018-07-30 20:20:29,115][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_0 - 10_folds.train_2.predict)=52.32%
# [ 2018-07-30 20:20:33,201][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_0 - 10_folds.train_3.predict)=53.16%
# [ 2018-07-30 20:20:37,381][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_0 - 10_folds.train_4.predict)=54.20%
# [ 2018-07-30 20:20:41,472][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_0 - 10_folds.train_5.predict)=53.52%
# [ 2018-07-30 20:20:45,540][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_0 - 10_folds.train_6.predict)=51.16%
# [ 2018-07-30 20:20:49,622][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_0 - 10_folds.train_7.predict)=52.56%
# [ 2018-07-30 20:20:53,730][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_0 - 10_folds.train_8.predict)=51.80%
# [ 2018-07-30 20:20:57,914][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_0 - 10_folds.train_9.predict)=53.28%
# [ 2018-07-30 20:20:58,260][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_0 - 10_folds.train_cv.predict)=52.34%
# [ 2018-07-30 20:20:58,262][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_0 - 10_folds.test.predict)=52.95%
# [ 2018-07-30 20:20:58,263][cascade_classifier.calc_accuracy] Accuracy(layer_2 - train.classifier_average)=52.34%
# [ 2018-07-30 20:20:58,265][cascade_classifier.calc_accuracy] Accuracy(layer_2 - test.classifier_average)=52.95%
# [ 2018-07-30 20:20:58,359][cascade_classifier.fit_transform] [layer=3] look_indexs=[0], X_cur_train.shape=(25000, 504), X_cur_test.shape=(25000, 504)
# [ 2018-07-30 20:21:02,305][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_0 - 10_folds.train_0.predict)=53.00%
# [ 2018-07-30 20:21:06,509][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_0 - 10_folds.train_1.predict)=52.56%
# [ 2018-07-30 20:21:10,590][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_0 - 10_folds.train_2.predict)=54.00%
# [ 2018-07-30 20:21:14,859][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_0 - 10_folds.train_3.predict)=53.84%
# [ 2018-07-30 20:21:19,771][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_0 - 10_folds.train_4.predict)=53.80%
# [ 2018-07-30 20:21:24,619][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_0 - 10_folds.train_5.predict)=51.96%
# [ 2018-07-30 20:21:28,788][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_0 - 10_folds.train_6.predict)=52.80%
# [ 2018-07-30 20:21:32,963][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_0 - 10_folds.train_7.predict)=51.28%
# [ 2018-07-30 20:21:37,142][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_0 - 10_folds.train_8.predict)=52.72%
# [ 2018-07-30 20:21:41,254][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_0 - 10_folds.train_9.predict)=50.92%
# [ 2018-07-30 20:21:41,638][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_0 - 10_folds.train_cv.predict)=52.69%
# [ 2018-07-30 20:21:41,640][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_0 - 10_folds.test.predict)=52.77%
# [ 2018-07-30 20:21:41,641][cascade_classifier.calc_accuracy] Accuracy(layer_3 - train.classifier_average)=52.69%
# [ 2018-07-30 20:21:41,642][cascade_classifier.calc_accuracy] Accuracy(layer_3 - test.classifier_average)=52.77%
# [ 2018-07-30 20:21:41,736][cascade_classifier.fit_transform] [layer=4] look_indexs=[0], X_cur_train.shape=(25000, 504), X_cur_test.shape=(25000, 504)
# [ 2018-07-30 20:21:45,573][kfold_wrapper.log_eval_metrics] Accuracy(layer_4 - estimator_0 - 10_folds.train_0.predict)=51.12%
# [ 2018-07-30 20:21:49,653][kfold_wrapper.log_eval_metrics] Accuracy(layer_4 - estimator_0 - 10_folds.train_1.predict)=53.24%
# [ 2018-07-30 20:21:53,759][kfold_wrapper.log_eval_metrics] Accuracy(layer_4 - estimator_0 - 10_folds.train_2.predict)=49.76%
# [ 2018-07-30 20:21:57,823][kfold_wrapper.log_eval_metrics] Accuracy(layer_4 - estimator_0 - 10_folds.train_3.predict)=52.72%
# [ 2018-07-30 20:22:02,036][kfold_wrapper.log_eval_metrics] Accuracy(layer_4 - estimator_0 - 10_folds.train_4.predict)=52.60%
# [ 2018-07-30 20:22:06,054][kfold_wrapper.log_eval_metrics] Accuracy(layer_4 - estimator_0 - 10_folds.train_5.predict)=53.56%
# [ 2018-07-30 20:22:10,206][kfold_wrapper.log_eval_metrics] Accuracy(layer_4 - estimator_0 - 10_folds.train_6.predict)=53.40%
# [ 2018-07-30 20:22:14,519][kfold_wrapper.log_eval_metrics] Accuracy(layer_4 - estimator_0 - 10_folds.train_7.predict)=53.72%
# [ 2018-07-30 20:22:19,050][kfold_wrapper.log_eval_metrics] Accuracy(layer_4 - estimator_0 - 10_folds.train_8.predict)=51.44%
# [ 2018-07-30 20:22:24,496][kfold_wrapper.log_eval_metrics] Accuracy(layer_4 - estimator_0 - 10_folds.train_9.predict)=54.88%
# [ 2018-07-30 20:22:25,055][kfold_wrapper.log_eval_metrics] Accuracy(layer_4 - estimator_0 - 10_folds.train_cv.predict)=52.64%
# [ 2018-07-30 20:22:25,060][kfold_wrapper.log_eval_metrics] Accuracy(layer_4 - estimator_0 - 10_folds.test.predict)=52.96%
# [ 2018-07-30 20:22:25,065][cascade_classifier.calc_accuracy] Accuracy(layer_4 - train.classifier_average)=52.64%
# [ 2018-07-30 20:22:25,067][cascade_classifier.calc_accuracy] Accuracy(layer_4 - test.classifier_average)=52.96%
# [ 2018-07-30 20:22:25,165][cascade_classifier.fit_transform] [layer=5] look_indexs=[0], X_cur_train.shape=(25000, 504), X_cur_test.shape=(25000, 504)
# [ 2018-07-30 20:22:30,480][kfold_wrapper.log_eval_metrics] Accuracy(layer_5 - estimator_0 - 10_folds.train_0.predict)=54.72%
# [ 2018-07-30 20:22:34,659][kfold_wrapper.log_eval_metrics] Accuracy(layer_5 - estimator_0 - 10_folds.train_1.predict)=54.16%
# [ 2018-07-30 20:22:38,860][kfold_wrapper.log_eval_metrics] Accuracy(layer_5 - estimator_0 - 10_folds.train_2.predict)=52.52%
# [ 2018-07-30 20:22:43,045][kfold_wrapper.log_eval_metrics] Accuracy(layer_5 - estimator_0 - 10_folds.train_3.predict)=52.48%
# [ 2018-07-30 20:22:47,218][kfold_wrapper.log_eval_metrics] Accuracy(layer_5 - estimator_0 - 10_folds.train_4.predict)=50.76%
# [ 2018-07-30 20:22:51,411][kfold_wrapper.log_eval_metrics] Accuracy(layer_5 - estimator_0 - 10_folds.train_5.predict)=51.84%
# [ 2018-07-30 20:22:55,594][kfold_wrapper.log_eval_metrics] Accuracy(layer_5 - estimator_0 - 10_folds.train_6.predict)=52.20%
# [ 2018-07-30 20:22:59,743][kfold_wrapper.log_eval_metrics] Accuracy(layer_5 - estimator_0 - 10_folds.train_7.predict)=51.52%
# [ 2018-07-30 20:23:03,931][kfold_wrapper.log_eval_metrics] Accuracy(layer_5 - estimator_0 - 10_folds.train_8.predict)=53.08%
# [ 2018-07-30 20:23:08,123][kfold_wrapper.log_eval_metrics] Accuracy(layer_5 - estimator_0 - 10_folds.train_9.predict)=52.04%
# [ 2018-07-30 20:23:08,514][kfold_wrapper.log_eval_metrics] Accuracy(layer_5 - estimator_0 - 10_folds.train_cv.predict)=52.53%
# [ 2018-07-30 20:23:08,515][kfold_wrapper.log_eval_metrics] Accuracy(layer_5 - estimator_0 - 10_folds.test.predict)=53.03%
# [ 2018-07-30 20:23:08,517][cascade_classifier.calc_accuracy] Accuracy(layer_5 - train.classifier_average)=52.53%
# [ 2018-07-30 20:23:08,518][cascade_classifier.calc_accuracy] Accuracy(layer_5 - test.classifier_average)=53.03%
# [ 2018-07-30 20:23:08,609][cascade_classifier.fit_transform] [layer=6] look_indexs=[0], X_cur_train.shape=(25000, 504), X_cur_test.shape=(25000, 504)
# [ 2018-07-30 20:23:12,547][kfold_wrapper.log_eval_metrics] Accuracy(layer_6 - estimator_0 - 10_folds.train_0.predict)=51.96%
# [ 2018-07-30 20:23:17,024][kfold_wrapper.log_eval_metrics] Accuracy(layer_6 - estimator_0 - 10_folds.train_1.predict)=53.08%
# [ 2018-07-30 20:23:21,739][kfold_wrapper.log_eval_metrics] Accuracy(layer_6 - estimator_0 - 10_folds.train_2.predict)=51.16%
# [ 2018-07-30 20:23:26,740][kfold_wrapper.log_eval_metrics] Accuracy(layer_6 - estimator_0 - 10_folds.train_3.predict)=51.72%
# [ 2018-07-30 20:23:30,916][kfold_wrapper.log_eval_metrics] Accuracy(layer_6 - estimator_0 - 10_folds.train_4.predict)=52.84%
# [ 2018-07-30 20:23:35,089][kfold_wrapper.log_eval_metrics] Accuracy(layer_6 - estimator_0 - 10_folds.train_5.predict)=50.60%
# [ 2018-07-30 20:23:39,287][kfold_wrapper.log_eval_metrics] Accuracy(layer_6 - estimator_0 - 10_folds.train_6.predict)=52.08%
# [ 2018-07-30 20:23:43,474][kfold_wrapper.log_eval_metrics] Accuracy(layer_6 - estimator_0 - 10_folds.train_7.predict)=52.68%
# [ 2018-07-30 20:23:47,677][kfold_wrapper.log_eval_metrics] Accuracy(layer_6 - estimator_0 - 10_folds.train_8.predict)=51.88%
# [ 2018-07-30 20:23:51,990][kfold_wrapper.log_eval_metrics] Accuracy(layer_6 - estimator_0 - 10_folds.train_9.predict)=52.32%
# [ 2018-07-30 20:23:52,381][kfold_wrapper.log_eval_metrics] Accuracy(layer_6 - estimator_0 - 10_folds.train_cv.predict)=52.03%
# [ 2018-07-30 20:23:52,383][kfold_wrapper.log_eval_metrics] Accuracy(layer_6 - estimator_0 - 10_folds.test.predict)=53.30%
# [ 2018-07-30 20:23:52,384][cascade_classifier.calc_accuracy] Accuracy(layer_6 - train.classifier_average)=52.03%
# [ 2018-07-30 20:23:52,386][cascade_classifier.calc_accuracy] Accuracy(layer_6 - test.classifier_average)=53.30%
# [ 2018-07-30 20:23:52,387][cascade_classifier.fit_transform] [Result][Optimal Level Detected] opt_layer_num=4, accuracy_train=52.69%, accuracy_test=52.77%
# [ 2018-07-30 20:23:52,529][cascade_classifier.transform] X_groups_test.shape=[(25000, 502)]
# [ 2018-07-30 20:23:52,568][cascade_classifier.transform] group_dims=[502]
# [ 2018-07-30 20:23:52,569][cascade_classifier.transform] X_test.shape=(25000, 502)
# [ 2018-07-30 20:23:52,608][cascade_classifier.transform] [layer=0] look_indexs=[0], X_cur_test.shape=(25000, 502)
# [ 2018-07-30 20:23:56,453][cascade_classifier.transform] [layer=1] look_indexs=[0], X_cur_test.shape=(25000, 504)
# [ 2018-07-30 20:24:00,284][cascade_classifier.transform] [layer=2] look_indexs=[0], X_cur_test.shape=(25000, 504)
# [ 2018-07-30 20:24:04,031][cascade_classifier.transform] [layer=3] look_indexs=[0], X_cur_test.shape=(25000, 504)
# ('Test Accuracy of CascadeExtraTrees = 52.720000 %', 'Layer :', 19)
# [[7239 5261]
#  [6559 5941]]
#
#
#              precision    recall  f1-score   support
#
#           0       0.52      0.58      0.55     12500
#           1       0.53      0.48      0.50     12500
#
# avg / total       0.53      0.53      0.53     25000
#
# (' Time ', '304.12', ' seconds')

# %%
print ("Opt_Cascade_num =",Accuracy.index(max(Accuracy)), " Accuracy =", max(Accuracy) ,
       "Time =" , np.sum(t[0:Accuracy.index(max(Accuracy))+1]))

import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
figure(figsize=(8, 6), dpi=100)
plt.plot(Accuracy, '-o', ms=20, lw=2, alpha=0.7, mfc='orange')
plt.ylabel('Accuracy')
plt.xlabel('Cascade numbers')
plt.show()
# Out:
# ('Opt_Cascade_num =', 0, ' Accuracy =', 53.23, 'Time =', 441.5)

# %%
Accuracy
# Out:
# [53.23,
#  52.82,
#  52.97,
#  52.56,
#  52.8,
#  52.98,
#  53.0,
#  52.71,
#  52.61,
#  52.86,
#  52.93,
#  52.94,
#  52.8,
#  52.79,
#  52.86,
#  52.94,
#  52.94,
#  53.09,
#  52.8,
#  52.72]
